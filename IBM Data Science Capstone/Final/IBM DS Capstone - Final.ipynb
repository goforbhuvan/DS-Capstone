# %% [markdown]
# <h1 align=center><font size = 5>Analyzing the neighborhoods in the city of Toronto</font></h1>

# %% [markdown]
# <h1 align=center><font size = 2>Bhuvanesh Selvakumar</font></h1>

# %% [markdown]
# ### Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size = 2>
#
# 1. [Introduction](#1)<br>
#     1.1. [Problem Statement](#1.1)<br>
#     1.2. [Methodology](#1.2)<br><br>
#
# 2. [Data Mining & Wrangling](#2)<br>
#     2.1. [Importing the necessary libraries for analysis](#2.1)<br>
#     2.2. [Importing open-source data from Wikipedia on Toronto's neighboorhoods and demography](#2.2)<br>
#     2.3. [Import Toronto's demography dataset from Wikipedia, extract and clean the data](#2.3)<br>
#     2.4. [Query location data from Foursquare API, and generate  map of Toronto using neighborhood dataset](#2.4)<br>
#     2.5. [Add Latitude, Longitude and Address of the neighborhoods to the demography dataframe](#2.5)<br><br>
#
# 3. [Analyze the neighborhoods using Foursquare API](#3)<br>
#     3.1. [Input user credentials to access Foursquare API](#3.1)<br>
#     3.2. [Define a function to query, sort data from Categories list and transfer them into a dataframe](#3.2)<br>
#     3.3. [Apply one-hot encoding](#3.3)<br>
#     3.4. [Identify neighborhoods with active Tamil population and evaluate if they have any Indian restaurants](#3.4)<br>
#     3.5. [Implement k-means clusterning to develop neighborhood clusters with Indian restaurants, and detailed analysis](#3.5)<br><br>
#
# 4. [Conclusions and Recommendations](#4)<br>
#     </font>
#     </div>

# %% [markdown]
# ### 1. Introduction <a class="anchor" id="1"></a>

# %% [markdown]
# > The Tamil community (native to Southern India, Sri Lanka and Malaysia) are an important part of the Indian diaspora in Canada, and offer an ethnic cuisine that is unique and different from the mainstream Indian cuisine. Rice is the staple dietary constituent and heavily leans on to use of ground spices and root herbs for cooking. While many Indian restaurants in Canada include popular South Indian recipes in their menu, the traditional/native recipes are often ruled out due to the very small target population, their extreme flavor and spice variations. However with the growing Tamil population in Toronto coupled with the community's interest in expanding the commercial/culture outreach, the demand and potential of success in opening a dedicated South Indian restaurant is very high.

# %% [markdown]
# #### 1.1. Problem Statement  <a class="anchor" id="1.1"></a>
#
# > An investor is considering the opportunity to open a South Indian restaurant in Toronto with a focus on offering authentic Tamil recipes along with popular Indian menu. The primary target customer base is the Indian diaspora in Canada due to their growing expectation and population in Toronto. The investor wants to identify neighborhoods with leading Tamil population as secondary ethnic group, as potential locations for starting the restaurant with limited/no business competition from other Indian restaurants.

# %% [markdown]
# #### 1.2. Methodology  <a class="anchor" id="1.2"></a>
#
# > 1. Data Mining - Data on Toronto's demography, neighborhoods and geo-locations were queried from the following websites:<br>
# >       a. Neighborhoods: https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=1008658788 <br>
# >       b. Demography: https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods <br>
# >       c. Activities: FourSquare API<br><br>
# > The "read_html" function was used to mine data on Toronto's neighborhoods, demography and postal codes from wikipedia. The postal code data was then used to run the geocoder function to query latitude and longitude for each of the boroughs in Toronto. The foursquare API function is used to generate insights on the neighborhoods and present them in a Folium map for visualization <br>
#
# > 2. Data Cleaning - Sort and organize the queried raw data into a structured dataframe. Concatenate columns and segregate data as necessary and required. Create a color trend for the data in the dataframe based on ethnicity and neighborhood <br><br>
# > The raw dataframe on Toronto's demography included many columns which were deemed unimportant for this project, and were aptly excluded using the drop function. Also, this dataframe presented the secondary ethnicity of the neighborhoods under the column "Ethnicity" where the Ethnicity and and its composition were printed as a single string. This limited the flexibility in using this data for further analysis. The "split" and "strip" functions were used to extract the data and tabulate them in separate columns. Using the geocoder function to query the latitude and longitude of the neighborhoods initially resulted in inaccurate results, as the output data included cities from US and UK due to similar neighbordhood names. To localize the search to Toronto, a new column (Name-ccat) was created to list the neighborhood names concatenated with the city name (x, Toronto). <br>
#
# > 3. Data Visualization - Generate map of Toronto and visualize different neighborhoods including their activities, boroughs, ethnicities etc. <br><br>
# > The neighborhoods are plotted on Toronto map using the "folium" function. To color-code the neighborhoods based on the secondary ethnicity and suburb region (Markham, Scarborough etc.), the "rgb2hex" function was used to generate colors for each neighborhood based on the above listed criteria and stored under the following columns: [Color_ethnicity, Color_FM].
#
# > 4. Data Processing - Apply filters to identify neighborhood clusters (one hot encoding, k-means clustering) with high frequency of Indian restaurants and Tamil population (data indexing)<br><br>
# > Foursquare API function's venue search feature was used to generate event category list for each neighborhood and keep count on the activity list. The output of this query is stored in the dataframe: "Toronto_venues".
#
# > 5. Data Analysis - Integrate tabuluar data (data frames) and visual analysis (color-coded maps) to identify the neighborhoods with high probability of success opening a South Indian restaurant and present summary of recommendations. Restaurants with high Tamil population and low frequency of Indian restaurants is deemed desirable and ideal for investment. Rank top 5 neighborhoods for opening the South Indian restaurant based on the ethnic composition of the neighborhoods.<br><br>
# >Analysis of the results began with one-hot encoding using "get_dummies" function to generate the mean frequency of each event category for every neighborhood. The top 5 activity/event list for each neighborhood was briefly reviewed to study the popular event list and identify the neighborhoods with high frequency of Indian restaurants. Next filters were applied to identify neighborhoods with high frequency of Indian restaurants and Tamil population. The search was subtly improvised to identify neighborhoods which have sizable Tamil population but dont have any Indian restaurant, as they are considered to be the oppotune neighborhoods for starting a new South Indian restaurant without any local business competition from other Indian restaurants. Next, k-means clustering was implemented using the frequency of Indian restaurants as grouping criteria, to organize the data under 3 clusters. "Cluster 0" lists neighborhoods which have low-medium frequency (0.02 - 0.0667) of Indian restaurants. "Cluster 1" includes the high frequency neighborhoods (0.1 - 0.2727) and "Cluster 2" contains neighborhoods with low frequency (0 - 0.01786) of Indian restaurants. Surprisingly, most of the cluster 1 neighborhoods were concentrated in Central and South-Western Toronto mostly around the University of Toronto, suggesting university students as the likely target population for the restaurants in these neighborhoods. The neighborhoods in the Eastern part of the city while having high residence population of Tamil community, have low frequency of Indian restuarants. Analysis of the visual and tabular data help triangulate and recommend the following 5 neighborhoods for starting a South-Indian restaurant: Rouge Hill, Malvern, Scarborough Village, Morningside, Scarborough City Centre.

# %% [markdown]
# ### 2. Data Mining & Wrangling <a class="anchor" id="2"></a>

# %% [markdown]
# #### 2.1. Importing the necessary libraries for analysis <a class="anchor" id="2.1"></a>

# %%
# Importing the necessary libraties for the project

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import requests
import random
import json
from pandas.io.json import json_normalize
from sklearn import preprocessing
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors

#!conda install -c conda-forge geopy --yes
# !pip install folium
# !pip install geocoder

import folium
# Out:
# Requirement already satisfied: folium in c:\users\bhuvan\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: branca in c:\users\bhuvan\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\bhuvan\anaconda3\lib\site-packages (from folium) (2.10.3)
# Requirement already satisfied: requests in c:\users\bhuvan\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: six in c:\users\bhuvan\anaconda3\lib\site-packages (from folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bhuvan\anaconda3\lib\site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: geocoder in c:\users\bhuvan\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: six in c:\users\bhuvan\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: click in c:\users\bhuvan\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in c:\users\bhuvan\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: ratelim in c:\users\bhuvan\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in c:\users\bhuvan\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: decorator in c:\users\bhuvan\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhuvan\anaconda3\lib\site-packages (from requests->geocoder) (2019.9.11)

# %% [markdown]
# #### 2.2. Importing open-source data from Wikipedia on Toronto's neighboorhoods and demography <a class="anchor" id="2.2"></a>

# %%
# Link to wikipedia neighborhoods
#url_nei = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
url_nei = "https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=1008658788"
wiki_Toronto_nei = pd.read_html(url_nei)[:]
wiki_Toronto_nei = pd.DataFrame(wiki_Toronto_nei[0])
wiki_Toronto_nei
wiki_Toronto_nei.groupby(by='Borough', axis=0)

#Count the number of boroughs                               
wiki_Toronto_borough = pd.unique(wiki_Toronto_nei['Borough'])
wiki_Toronto_borough_count = wiki_Toronto_nei['Borough'].value_counts()
wiki_Toronto_borough_count

#Reorganize the dataframe and sort them in ascending order
wiki_Toronto_nei = wiki_Toronto_nei.sort_values(by=['Borough'], ascending = True).reset_index()
#wiki_Toronto_nei.reset_index(inplace=True)
wiki_Toronto_nei.drop(['index'], axis=1, inplace=True)
wiki_Toronto_nei.set_index
wiki_Toronto_nei.index.name = 'index'
#wiki_Toronto_nei.index = range(len(wiki_Toronto_nei['Borough']))

#wiki_Toronto_nei
#wiki_Toronto_nei[wiki_Toronto_nei['Postal Code'] == 'M5A']

# %%
wiki_Toronto_nei.shape
print('There are {} rows and {} columns in the Toronto neighborhood dataframe'.format(wiki_Toronto_nei.shape[0],
                                                                                       wiki_Toronto_nei.shape[1]))
# Out:
# There are 180 rows and 3 columns in the Toronto neighborhood dataframe

# %%
#Getting Latitudes and Longtitudes from Postcodes and integrate it with the neighboorhood dataframe

#!pip install pgeocode
import pgeocode
Toronto_geocoder = pgeocode.Nominatim('ca')

Toronto_boroughs_LL = Toronto_geocoder.query_postal_code(i for i in wiki_Toronto_nei['Postal Code'])[['postal_code',
                                                                                                      'latitude',
                                                                                                      'longitude']]
Toronto_boroughs_LL
wiki_Toronto_nei[['latitude','longitude']] = Toronto_boroughs_LL[['latitude','longitude']]
#wiki_Toronto_nei

# %% [markdown]
# #### 2.3. Import Toronto's demography dataset from Wikipedia, extract and clean the data <a class="anchor" id="2.3"></a>

# %%
def extract_ethnicity(row): 
    y = wiki_Toronto_dem['Ethnicity'][row]
    y = re.search('\(([^)]+)', y).group(1)
    y =  float(y.strip('%'))
    #y =  y.strip('%')

    return y


## Query data of Toronto demograohy from Wikipedia

#!pip install wikipedia #Uncomment this line after installing the first installation of Wikipedia library
import wikipedia as wp
import pandas as pd
import re

url_dem = "https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods"
wiki_Toronto_dem = pd.read_html(url_dem)[:]
wiki_Toronto_dem = pd.DataFrame(wiki_Toronto_dem[1])    
#wiki_Toronto_dem.rename(columns={"Second most common language (after English) by name" : "Ethnicity"}, inplace = True)
#wiki_Toronto_dem.groupby(by='Ethnicity', axis=0)

for i in range(2,6):
    x = pd.read_html(url_dem)[:]
    x = pd.DataFrame(x[i])
    wiki_Toronto_dem = wiki_Toronto_dem.append(x, ignore_index=False)

wiki_Toronto_dem.rename(columns={"Second most common language (after English) by name" : "Ethnicity"}, inplace = True)
wiki_Toronto_dem['Ethnicity']
wiki_Toronto_dem.reset_index(inplace=True)

#----------------------------------------------------------------------------------------------------------------------


# Creating a new column and remove unused columns

wiki_Toronto_dem['Ethnicity Percentage (%)'] = ''

for i in range(wiki_Toronto_dem.shape[0]):
    if set(['Map','Census Tracts','Second most common language (after English) by percentage']).issubset(wiki_Toronto_dem):
        wiki_Toronto_dem.drop(columns = ['Map','Census Tracts','Second most common language (after English) by percentage'], axis = 1, inplace=True)
    else:
        pass
    
wiki_Toronto_dem = wiki_Toronto_dem.dropna()

wiki_Toronto_dem.drop(['index'], axis=1, inplace=True)
wiki_Toronto_dem.set_index
wiki_Toronto_dem.index.name = 'index'
wiki_Toronto_dem.index = range(len(wiki_Toronto_dem['Ethnicity']))
wiki_Toronto_dem

#-----------------------------------------------------------------------------------------------------------------------


# Extract the ethnicty and save it in Ethnicity percentage columnn

out = []
for i in range(len(wiki_Toronto_dem['Ethnicity'])):
    out.append(extract_ethnicity(i))

wiki_Toronto_dem['Ethnicity Percentage (%)'] = out
wiki_Toronto_dem['Ethnicity_new'] = wiki_Toronto_dem['Ethnicity'].str.split('(').str[0]

for i in range(len(wiki_Toronto_dem['Ethnicity_new'])):
     wiki_Toronto_dem['Ethnicity_new'][i] = wiki_Toronto_dem['Ethnicity_new'][i].strip()
        
wiki_Toronto_dem
#wiki_Toronto_dem['Ethnicity_new'].value_counts()


#------------------------------------------------------------------------------------------------------------------------

#Create an new column listing the names of neighborhood concatenated with "Toronto" to make the address search easier

temp = wiki_Toronto_dem['Name'] + ', Toronto'
wiki_Toronto_dem.insert(1,'Name-ccat',temp)
wiki_Toronto_dem


#------------------------------------------------------------------------------------------------------------------------

#Clean the neighborhood names (row 1, 55)

pd.set_option('display.max_rows', 500)
wiki_Toronto_dem['Name'][1] = wiki_Toronto_dem['Name'][1].split('/')[0]
wiki_Toronto_dem['Name'][55] = wiki_Toronto_dem['Name'][55].split('/')[0]

wiki_Toronto_dem.head()
# Out:
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 Name                                      Name-ccat  FM  \
# 0      Crescent Town                         Crescent Town, Toronto  EY
# 1  Governor's Bridge  Governor's Bridge/Bennington Heights, Toronto  EY
# 2            Leaside                               Leaside, Toronto  EY
# 3  O'Connor–Parkview                     O'Connor–Parkview, Toronto  EY
# 4      Old East York                         Old East York, Toronto  EY
#
#   Population  Land area (km2) Density (people/km2)  \
# 0       8157             0.40                20393
# 1       2112             1.87                 1129
# 2      13876             2.81                 4938
# 3      17740             4.94                 3591
# 4      52220             7.94                 6577
#
#    % Change in Population since 2001 Average Income  Transit Commuting %  \
# 0                              -10.0          23021                 24.5
# 1                                4.0         129904                  7.1
# 2                                3.0          82670                  9.7
# 3                               -6.1          33517                 15.8
# 4                               -4.6          33172                 22.0
#
#    % Renters         Ethnicity  Ethnicity Percentage (%) Ethnicity_new
# 0       20.3   Bengali (18.1%)                      18.1       Bengali
# 1       13.3     Polish (1.4%)                       1.4        Polish
# 2       10.5  Bulgarian (0.4%)                       0.4     Bulgarian
# 3       19.4       Urdu (3.2%)                       3.2          Urdu
# 4       19.1      Greek (4.3%)                       4.3         Greek

# %% [markdown]
# #### 2.4. Query location data from Foursquare API, and generate  map of Toronto using neighborhood dataset <a class="anchor" id="2.4"></a>

# %%
# Use Nominatim function to generate map of Toronto

address = 'Toronto, Ontario'
geolocator = Nominatim(user_agent="Toronto_explorer")
Toronto_location = geolocator.geocode(address, timeout = None)
Toronto_latitude = Toronto_location.latitude
Toronto_longitude = Toronto_location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(Toronto_latitude, Toronto_longitude))


# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[Toronto_latitude, Toronto_longitude], zoom_start=11)

wiki_Toronto_nei = wiki_Toronto_nei.dropna()


# add markers to map
for lat, lng, label in zip(wiki_Toronto_nei['latitude'], wiki_Toronto_nei['longitude'], wiki_Toronto_nei['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_61fae5645c1947be82e85065ced7cb0d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_61fae5645c1947be82e85065ced7cb0d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_61fae5645c1947be82e85065ced7cb0d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_61fae5645c1947be82e85065ced7cb0d%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### 2.5. Add Latitude, Longitude and Address of the neighborhoods to the demography dataframe <a class="anchor" id="2.5"></a>

# %%
# Adding address to the Dataframe 

Toronto_locator =  Nominatim(user_agent="FourSquare_Toronto")
#Toronto_locator.geocode(Toronto_dem_LL[i])
wiki_Toronto_dem['Address'] = ''
wiki_Toronto_dem['Latitude'] = ''
wiki_Toronto_dem['Longitude'] = ''
    
for i in range(len(wiki_Toronto_dem['Name-ccat'])):
    if bool(Toronto_locator.geocode(wiki_Toronto_dem['Name-ccat'][i])) == True:
        wiki_Toronto_dem['Address'][i] = Toronto_locator.geocode(wiki_Toronto_dem['Name-ccat'][i])[0]
    else:
        #return None 
        wiki_Toronto_dem['Address'][i] = 0

#wiki_Toronto_dem
# Out:
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
    
#Making a temporary copy of the Dataframe for ease of testing the code

x = wiki_Toronto_dem
x = x[x['Address'] != 0]
x.reset_index(drop=True, inplace=True)
x

def find_LL(row):
    latitude = Toronto_locator.geocode(x['Name-ccat'][row],timeout=None)[1][0]
    longitude = Toronto_locator.geocode(x['Name-ccat'][row],timeout=None)[1][1]
    return latitude, longitude


for i in range(len(x['Name'])):
    x['Latitude'].loc[i] = find_LL(i)[0]
    x['Longitude'].loc[i] = find_LL(i)[1]
    #lati = find_LL(i)[0]
    #long = find_LL(i)[1]
    #x.append({'Latitude':lati,'Longitude':long}, ignore_index=True)

wiki_Toronto_dem = x
# Out:
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
# Color code the neighborhoods based on the highest secondary ethnicty

neigh_labels = wiki_Toronto_dem['Ethnicity_new'].unique()
color_array = cm.rainbow(np.linspace(0, 1, len(neigh_labels)))
color_array = [colors.rgb2hex(i) for i in color_array]
#color_array

for i in range(len(neigh_labels)):
    wiki_Toronto_dem.loc[wiki_Toronto_dem['Ethnicity_new'] == neigh_labels[i] , "Color_ethnicity"] = color_array[i]
    
#wiki_Toronto_dem


#-----------------------------------------------------------------------------------------------------------------


# Color code the neighborhoods based on the neighborhoods

neigh_labels = wiki_Toronto_dem['FM'].unique()
color_array = cm.rainbow(np.linspace(0, 1, len(neigh_labels)))
color_array = [colors.rgb2hex(i) for i in color_array]
#color_array

for i in range(len(neigh_labels)):
    wiki_Toronto_dem.loc[wiki_Toronto_dem['FM'] == neigh_labels[i] , "Color_FM"] = color_array[i]
    
#wiki_Toronto_dem

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[Toronto_latitude, Toronto_longitude], zoom_start=11)

wiki_Toronto_nei = wiki_Toronto_nei.dropna()


# add markers to map
for lat, lng, label, area, color_ethnicity, color_FM in zip(wiki_Toronto_dem['Latitude'],
                                                      wiki_Toronto_dem['Longitude'],
                                                      wiki_Toronto_dem['Ethnicity_new'],
                                                      wiki_Toronto_dem['Name'],                                                            
                                                      wiki_Toronto_dem['Color_ethnicity'],
                                                      wiki_Toronto_dem['Color_FM']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=color_FM,
        fill=True,
        fill_color=color_FM,
        fill_opacity=1,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_57b51ff3393847bf88b320bc703c424a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_57b51ff3393847bf88b320bc703c424a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_57b51ff3393847bf88b320bc703c424a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_57b51ff3393847bf88b320bc703c424a%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 3. Analyze the neighborhoods using Foursquare API <a class="anchor" id="3"></a>

# %% [markdown]
# #### 3.1. Input user credentials to access Foursquare API <a class="anchor" id="3.1"></a>

# %%
CLIENT_ID = 'RF0UYLVZDZ3W4IBJOOHUTN3LZZY1YTHCOHODTMLWHSN11HJQ' # your Foursquare ID
CLIENT_SECRET = 'Z1LAGZCWCJOMUQKQ53VXXBCPHGHZD1EOG3O4R0XIFK1RCZYB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RF0UYLVZDZ3W4IBJOOHUTN3LZZY1YTHCOHODTMLWHSN11HJQ
# CLIENT_SECRET:Z1LAGZCWCJOMUQKQ53VXXBCPHGHZD1EOG3O4R0XIFK1RCZYB

# %% [markdown]
# #### 3.2. Define a function to query, sort data from Categories list and transfer them into a dataframe <a class="anchor" id="3.2"></a>

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
#results['response']['groups'][0]['items']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)



# type your answer here
Toronto_venues = getNearbyVenues(names=wiki_Toronto_dem['Name-ccat'],
                                   latitudes=wiki_Toronto_dem['Latitude'],
                                   longitudes=wiki_Toronto_dem['Longitude']
                                  )

#Toronto_venues
# Out:
# Crescent Town, Toronto
# Governor's Bridge/Bennington Heights, Toronto
# Leaside, Toronto
# O'Connor–Parkview, Toronto
# Old East York, Toronto
# Thorncliffe Park, Toronto
# Alderwood, Toronto
# Centennial, Toronto
# Clairville, Toronto
# Eatonville, Toronto
# Humber Heights, Toronto
# Humberwood, Toronto
# Humber Valley Village, Toronto
# Islington – Six Points, Toronto
# Kingsview Village, Toronto
# Long Branch, Toronto
# Markland Wood, Toronto
# Mimico, Toronto
# New Toronto, Toronto
# Princess Gardens, Toronto
# Agincourt, Toronto
# Alexandra Park, Toronto
# Allenby, Toronto
# Amesbury, Toronto
# Armour Heights, Toronto
# Banbury, Toronto
# Bathurst Manor, Toronto
# Bay Street Corridor, Toronto
# Bayview Village, Toronto
# Bayview Woods – Steeles, Toronto
# Trinity–Bellwoods, Toronto
# Upper Beaches, Toronto
# Victoria Village, Toronto
# Wallace Emerson, Toronto
# West Deane Park, Toronto
# West Hill, Toronto
# West Rouge, Toronto
# Westminster, Toronto
# Westmount, Toronto
# Weston, Toronto
# Wexford, Toronto
# Willowdale, Toronto
# Wilson Heights, Toronto
# Woburn, Toronto
# Wychwood, Toronto
# York Mills, Toronto
# York University Heights, Toronto
# Yorkville, Toronto

# %%
#print(Toronto_venues.shape)
Toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                Neighborhood Latitude  \
# Neighborhood
# Agincourt, Toronto                                                12
# Alderwood, Toronto                                                 7
# Alexandra Park, Toronto                                          100
# Allenby, Toronto                                                   7
# Amesbury, Toronto                                                  6
# Armour Heights, Toronto                                            3
# Banbury, Toronto                                                   6
# Bathurst Manor, Toronto                                            4
# Bay Street Corridor, Toronto                                     100
# Bayview Village, Toronto                                          13
# Bayview Woods – Steeles, Toronto                                   1
# Bedford Park, Toronto                                              2
# Bendale, Toronto                                                   7
# Birch Cliff, Toronto                                               4
# Bloor West Village, Toronto                                       38
# Bracondale Hill, Toronto                                           6
# Branson, Toronto                                                   8
# Bridle Path, Toronto                                               1
# Brockton, Toronto                                                 18
# Cabbagetown, Toronto                                              50
# Caribou Park, Toronto                                             12
# Carleton Village, Toronto                                          4
# Casa Loma, Toronto                                                23
# Centennial, Toronto                                                2
# Chaplin Estates, Toronto                                          18
# Christie Pits, Toronto                                            12
# Church and Wellesley, Toronto                                     31
# Clairlea, Toronto                                                  7
# Clairville, Toronto                                                5
# Cliffcrest, Toronto                                                5
# Cliffside, Toronto                                                 7
# Corktown, Toronto                                                 35
# Crescent Town, Toronto                                             4
# Cricket Club, Toronto                                             10
# Davenport, Toronto                                                 6
# Davisville, Toronto                                               40
# Deer Park, Toronto                                                55
# Discovery District, Toronto                                       65
# Don Mills, Toronto                                                64
# Don Valley Village, Toronto                                       11
# Dorset Park, Toronto                                              10
# Dovercourt Park, Toronto                                           6
# Downsview, Toronto                                                10
# Dufferin Grove, Toronto                                           50
# Earlscourt, Toronto                                               19
# East Danforth, Toronto                                             4
# Eatonville, Toronto                                               11
# Eglinton East, Toronto                                             6
# Elia (Jane and Finch), Toronto                                    23
# Fashion District, Toronto                                         76
# Financial District, Toronto                                      100
# Flemingdon Park, Toronto                                          12
# Forest Hill, Toronto                                               4
# Fort York/Liberty Village, Toronto                                18
# Garden District, Toronto                                          66
# Glen Park, Toronto                                                 8
# Governor's Bridge/Bennington Heights, Toronto                      4
# Grange Park, Toronto                                             100
# Graydon Hall, Toronto                                              4
# Guildwood, Toronto                                                 5
# Harbord Village, Toronto                                          40
# Harbourfront / CityPlace, Toronto                                 45
# Harwood, Toronto                                                  14
# Henry Farm, Toronto                                                4
# High Park North, Toronto                                           5
# Highland Creek, Toronto                                            2
# Hillcrest, Toronto                                                43
# Hoggs Hollow, Toronto                                              9
# Humber Heights, Toronto                                            6
# Humber Summit, Toronto                                             4
# Humber Valley Village, Toronto                                     5
# Humberlea, Toronto                                                 4
# Humberwood, Toronto                                                5
# Humewood–Cedarvale, Toronto                                        5
neighborhood Longitude  Venue  \
# Neighborhood
# Agincourt, Toronto                                                 12     12
# Alderwood, Toronto                                                  7      7
# Alexandra Park, Toronto                                           100    100
# Allenby, Toronto                                                    7      7
# Amesbury, Toronto                                                   6      6
# Armour Heights, Toronto                                             3      3
# Banbury, Toronto                                                    6      6
# Bathurst Manor, Toronto                                             4      4
# Bay Street Corridor, Toronto                                      100    100
# Bayview Village, Toronto                                           13     13
# Bayview Woods – Steeles, Toronto                                    1      1
# Bedford Park, Toronto                                               2      2
# Bendale, Toronto                                                    7      7
# Birch Cliff, Toronto                                                4      4
# Bloor West Village, Toronto                                        38     38
# Bracondale Hill, Toronto                                            6      6
# Branson, Toronto                                                    8      8
# Bridle Path, Toronto                                                1      1
# Brockton, Toronto                                                  18     18
# Cabbagetown, Toronto                                               50     50
# Caribou Park, Toronto                                              12     12
# Carleton Village, Toronto                                           4      4
# Casa Loma, Toronto                                                 23     23
# Centennial, Toronto                                                 2      2
# Chaplin Estates, Toronto                                           18     18
# Christie Pits, Toronto                                             12     12
# Church and Wellesley, Toronto                                      31     31
# Clairlea, Toronto                                                   7      7
# Clairville, Toronto                                                 5      5
# Cliffcrest, Toronto                                                 5      5
# Cliffside, Toronto                                                  7      7
# Corktown, Toronto                                                  35     35
# Crescent Town, Toronto                                              4      4
# Cricket Club, Toronto                                              10     10
# Davenport, Toronto                                                  6      6
# Davisville, Toronto                                                40     40
# Deer Park, Toronto                                                 55     55
# Discovery District, Toronto                                        65     65
# Don Mills, Toronto                                                 64     64
# Don Valley Village, Toronto                                        11     11
# Dorset Park, Toronto                                               10     10
# Dovercourt Park, Toronto                                            6      6
# Downsview, Toronto                                                 10     10
# Dufferin Grove, Toronto                                            50     50
# Earlscourt, Toronto                                                19     19
# East Danforth, Toronto                                              4      4
# Eatonville, Toronto                                                11     11
# Eglinton East, Toronto                                              6      6
# Elia (Jane and Finch), Toronto                                     23     23
# Fashion District, Toronto                                          76     76
# Financial District, Toronto                                       100    100
# Flemingdon Park, Toronto                                           12     12
# Forest Hill, Toronto                                                4      4
# Fort York/Liberty Village, Toronto                                 18     18
# Garden District, Toronto                                           66     66
# Glen Park, Toronto                                                  8      8
# Governor's Bridge/Bennington Heights, Toronto                       4      4
# Grange Park, Toronto                                              100    100
# Graydon Hall, Toronto                                               4      4
# Guildwood, Toronto                                                  5      5
# Harbord Village, Toronto                                           40     40
# Harbourfront / CityPlace, Toronto                                  45     45
# Harwood, Toronto                                                   14     14
# Henry Farm, Toronto                                                 4      4
# High Park North, Toronto                                            5      5
# Highland Creek, Toronto                                             2      2
# Hillcrest, Toronto                                                 43     43
# Hoggs Hollow, Toronto                                               9      9
# Humber Heights, Toronto                                             6      6
# Humber Summit, Toronto                                              4      4
# Humber Valley Village, Toronto                                      5      5
# Humberlea, Toronto                                                  4      4
# Humberwood, Toronto                                                 5      5
# Humewood–Cedarvale, Toronto                                         5      5
# Ionview, Toronto                                                    3      3
# Islington – Six Points, Toronto                                    13     13
# Junction Triangle, Toronto                                         40     40
# Kensington Market, Toronto                                         87     87
# Kingsview Village, Toronto                                          1      1
# L'Amoreaux, Toronto                                                 7      7
# Lambton, Toronto                                                    3      3
# Lansing, Toronto                                                    5      5
# Lawrence Heights, Toronto                                          89     89
# Lawrence Manor, Toronto                                             5      5
# Lawrence Park, Toronto                                             54     54
# Leaside, Toronto                                                    4      4
# Ledbury Park, Toronto                                              10     10
# Leslieville, Toronto                                               55     55
# Little Italy, Toronto                                              69     69
# Little Portugal, Toronto                                           37     37
# Long Branch, Toronto                                                9      9
# Lytton Park, Toronto                                                5      5
# Malvern, Toronto                                                   15     15
# Maple Leaf, Toronto                                                 2      2
# Markland Wood, Toronto                                              4      4
# Maryvale, Toronto                                                  20     20
# Milliken, Toronto                                                  39     39
# Mimico, Toronto                                                     4      4
# Moore Park, Toronto                                                 3      3
# Morningside, Toronto                                               12     12
# Mount Dennis, Toronto                                               8      8
# New Toronto, Toronto                                               18     18
# Newtonbrook, Toronto                                                4      4
# Niagara, Toronto                                                   53     53
# North York City Centre, Toronto                                     3      3
# O'Connor–Parkview, Toronto                                          8      8
# Oakridge, Toronto                                                   6      6
# Old East York, Toronto                                              3      3
# Old Mill/Baby Point, Toronto                                        4      4
# Parkdale, Toronto                                                  43     43
# Parkway Forest, Toronto                                             6      6
# Parkwoods, Toronto                                                 13     13
# Pelmo Park, Toronto                                                 3      3
# Playter Estates, Toronto                                           56     56
# Pleasant View, Toronto                                             15     15
# Port Lands, Toronto                                                17     17
# Port Union, Toronto                                                 3      3
# Princess Gardens, Toronto                                          85     85
# Regent Park/Trefann Court, Toronto                                 30     30
# Richview, Toronto                                                   5      5
# Riverdale, Toronto                                                 31     31
# Roncesvalles, Toronto                                              38     38
# Rosedale, Toronto                                                   5      5
# Rouge Hill, Toronto                                                 2      2
# Rouge, Toronto                                                      3      3
# Runnymede, Toronto                                                 41     41
# Scarborough City Centre, Toronto                                    6      6
# Scarborough Junction, Toronto                                       4      4
# Scarborough Village, Toronto                                       10     10
# Seaton Village, Toronto                                            30     30
# Silverthorn, Toronto                                               14     14
# Smithfield, Toronto                                                19     19
# South Hill, Toronto                                                28     28
# St. James Town, Toronto                                            31     31
# Steeles, Toronto                                                    1      1
# Summerhill, Toronto                                                36     36
# Sunnylea, Toronto                                                   4      4
# Swansea, Toronto                                                    6      6
# Tam O'Shanter – Sullivan, Toronto                                   8      8
# The Annex, Toronto                                                 43     43
# The Beaches, Toronto                                               49     49
# The Danforth, Toronto                                              30     30
# The Elms, Toronto                                                   5      5
# The Junction, Toronto                                              59     59
# The Kingsway, Toronto                                              33     33
# The Queensway, Toronto                                             26     26
# Thistletown, Toronto                                               11     11
# Thorncliffe Park, Toronto                                          25     25
# Toronto Islands, Toronto                                            4      4
# Trinity–Bellwoods, Toronto                                         43     43
# Upper Beaches, Toronto                                              6      6
# Victoria Village, Toronto                                           3      3
# Wallace Emerson, Toronto                                           19     19
# West Hill, Toronto                                                 32     32
# West Rouge, Toronto                                                 1      1
# Westminster, Toronto                                                4      4
# Westmount, Toronto                                                  3      3
# Weston, Toronto                                                    16     16
# Wexford, Toronto                                                   19     19
# Willowdale, Toronto                                                47     47
# Wilson Heights, Toronto                                             9      9
# Woburn, Toronto                                                    21     21
# Wychwood, Toronto                                                  53     53
# York Mills, Toronto                                                15     15
# York University Heights, Toronto                                   20     20
# Yorkville, Toronto                                                100    100
#
#                                                Venue Latitude  \
# Neighborhood
# Agincourt, Toronto                                         12
# Alderwood, Toronto                                          7
# Alexandra Park, Toronto                                   100
# Allenby, Toronto                                            7
# Amesbury, Toronto                                           6
# Armour Heights, Toronto                                     3
# Banbury, Toronto                                            6
# Bathurst Manor, Toronto                                     4
# Bay Street Corridor, Toronto                              100
# Bayview Village, Toronto                                   13
# Bayview Woods – Steeles, Toronto                            1
# Bedford Park, Toronto                                       2
# Bendale, Toronto                                            7
# Birch Cliff, Toronto                                        4
# Bloor West Village, Toronto                                38
# Bracondale Hill, Toronto                                    6
# Branson, Toronto                                            8
# Bridle Path, Toronto                                        1
# Brockton, Toronto                                          18
# Cabbagetown, Toronto                                       50
# Caribou Park, Toronto                                      12
# Carleton Village, Toronto                                   4
# Casa Loma, Toronto                                         23
# Centennial, Toronto                                         2
# Chaplin Estates, Toronto                                   18
# Christie Pits, Toronto                                     12
# Church and Wellesley, Toronto                              31
# Clairlea, Toronto                                           7
# Clairville, Toronto                                         5
# Cliffcrest, Toronto                                         5
# Cliffside, Toronto                                          7
# Corktown, Toronto                                          35
# Crescent Town, Toronto                                      4
# Cricket Club, Toronto                                      10
# Davenport, Toronto                                          6
# Davisville, Toronto                                        40
# Deer Park, Toronto                                         55
# Discovery District, Toronto                                65
# Don Mills, Toronto                                         64
# Don Valley Village, Toronto                                11
# Dorset Park, Toronto                                       10
# Dovercourt Park, Toronto                                    6
# Downsview, Toronto                                         10
# Dufferin Grove, Toronto                                    50
# Earlscourt, Toronto                                        19
# East Danforth, Toronto                                      4
# Eatonville, Toronto                                        11
# Eglinton East, Toronto                                      6
# Elia (Jane and Finch), Toronto                             23
# Fashion District, Toronto                                  76
# Financial District, Toronto                               100
# Flemingdon Park, Toronto                                   12
# Forest Hill, Toronto                                        4
# Fort York/Liberty Village, Toronto                         18
# Garden District, Toronto                                   66
# Glen Park, Toronto                                          8
# Governor's Bridge/Bennington Heights, Toronto               4
# Grange Park, Toronto                                      100
# Graydon Hall, Toronto                                       4
# Guildwood, Toronto                                          5
# Harbord Village, Toronto                                   40
# Harbourfront / CityPlace, Toronto                          45
# Harwood, Toronto                                           14
# Henry Farm, Toronto                                         4
# High Park North, Toronto                                    5
# Highland Creek, Toronto                                     2
# Hillcrest, Toronto                                         43
# Hoggs Hollow, Toronto                                       9
# Humber Heights, Toronto                                     6
# Humber Summit, Toronto                                      4
# Humber Valley Village, Toronto                              5
# Humberlea, Toronto                                          4
# Humberwood, Toronto                                         5
# Humewood–Cedarvale, Toronto                                 5
# Ionview, Toronto                                            3
# Islington – Six Points, Toronto                            13
# Junction Triangle, Toronto                                 40
# Kensington Market, Toronto                                 87
# Kingsview Village, Toronto                                  1
# L'Amoreaux, Toronto                                         7
# Lambton, Toronto                                            3
# Lansing, Toronto                                            5
# Lawrence Heights, Toronto                                  89
# Lawrence Manor, Toronto                                     5
# Lawrence Park, Toronto                                     54
# Leaside, Toronto                                            4
# Ledbury Park, Toronto                                      10
# Leslieville, Toronto                                       55
# Little Italy, Toronto                                      69
# Little Portugal, Toronto                                   37
# Long Branch, Toronto                                        9
# Lytton Park, Toronto                                        5
# Malvern, Toronto                                           15
# Maple Leaf, Toronto                                         2
# Markland Wood, Toronto                                      4
# Maryvale, Toronto                                          20
# Milliken, Toronto                                          39
# Mimico, Toronto                                             4
# Moore Park, Toronto                                         3
# Morningside, Toronto                                       12
# Mount Dennis, Toronto                                       8
# New Toronto, Toronto                                       18
# Newtonbrook, Toronto                                        4
# Niagara, Toronto                                           53
# North York City Centre, Toronto                             3
# O'Connor–Parkview, Toronto                                  8
# Oakridge, Toronto                                           6
# Old East York, Toronto                                      3
# Old Mill/Baby Point, Toronto                                4
# Parkdale, Toronto                                          43
# Parkway Forest, Toronto                                     6
# Parkwoods, Toronto                                         13
# Pelmo Park, Toronto                                         3
# Playter Estates, Toronto                                   56
# Pleasant View, Toronto                                     15
# Port Lands, Toronto                                        17
# Port Union, Toronto                                         3
# Princess Gardens, Toronto                                  85
# Regent Park/Trefann Court, Toronto                         30
# Richview, Toronto                                           5
# Riverdale, Toronto                                         31
# Roncesvalles, Toronto                                      38
# Rosedale, Toronto                                           5
# Rouge Hill, Toronto                                         2
# Rouge, Toronto                                              3
# Runnymede, Toronto                                         41
# Scarborough City Centre, Toronto                            6
# Scarborough Junction, Toronto                               4
# Scarborough Village, Toronto                               10
# Seaton Village, Toronto                                    30
# Silverthorn, Toronto                                       14
# Smithfield, Toronto                                        19
# South Hill, Toronto                                        28
# St. James Town, Toronto                                    31
# Steeles, Toronto                                            1
# Summerhill, Toronto                                        36
# Sunnylea, Toronto                                           4
# Swansea, Toronto                                            6
# Tam O'Shanter – Sullivan, Toronto                           8
# The Annex, Toronto                                         43
# The Beaches, Toronto                                       49
# The Danforth, Toronto                                      30
# The Elms, Toronto                                           5
# The Junction, Toronto                                      59
# The Kingsway, Toronto                                      33
# The Queensway, Toronto                                     26
# Thistletown, Toronto                                       11
# Thorncliffe Park, Toronto                                  25
# Toronto Islands, Toronto                                    4
# Trinity–Bellwoods, Toronto                                 43
# Upper Beaches, Toronto                                      6
# Victoria Village, Toronto                                   3
# Wallace Emerson, Toronto                                   19
# West Hill, Toronto                                         32
# West Rouge, Toronto                                         1
# Westminster, Toronto                                        4
# Westmount, Toronto                                          3
# Weston, Toronto                                            16
# Wexford, Toronto                                           19
# Willowdale, Toronto                                        47
# Wilson Heights, Toronto                                     9
# Woburn, Toronto                                            21
# Wychwood, Toronto                                          53
# York Mills, Toronto                                        15
# York University Heights, Toronto                           20
# Yorkville, Toronto                                        100
#
#                                                Venue Longitude  Venue Category
# Neighborhood
# Agincourt, Toronto                                          12              12
# Alderwood, Toronto                                           7               7
# Alexandra Park, Toronto                                    100             100
# Allenby, Toronto                                             7               7
# Amesbury, Toronto                                            6               6
# Armour Heights, Toronto                                      3               3
# Banbury, Toronto                                             6               6
# Bathurst Manor, Toronto                                      4               4
# Bay Street Corridor, Toronto                               100             100
# Bayview Village, Toronto                                    13              13
# Bayview Woods – Steeles, Toronto                             1               1
# Bedford Park, Toronto                                        2               2
# Bendale, Toronto                                             7               7
# Birch Cliff, Toronto                                         4               4
# Bloor West Village, Toronto                                 38              38
# Bracondale Hill, Toronto                                     6               6
# Branson, Toronto                                             8               8
# Bridle Path, Toronto                                         1               1
# Brockton, Toronto                                           18              18
# Cabbagetown, Toronto                                        50              50
# Caribou Park, Toronto                                       12              12
# Carleton Village, Toronto                                    4               4
# Casa Loma, Toronto                                          23              23
# Centennial, Toronto                                          2               2
# Chaplin Estates, Toronto                                    18              18
# Christie Pits, Toronto                                      12              12
# Church and Wellesley, Toronto                               31              31
# Clairlea, Toronto                                            7               7
# Clairville, Toronto                                          5               5
# Cliffcrest, Toronto                                          5               5
# Cliffside, Toronto                                           7               7
# Corktown, Toronto                                           35              35
# Crescent Town, Toronto                                       4               4
# Cricket Club, Toronto                                       10              10
# Davenport, Toronto                                           6               6
# Davisville, Toronto                                         40              40
# Deer Park, Toronto                                          55              55
# Discovery District, Toronto                                 65              65
# Don Mills, Toronto                                          64              64
# Don Valley Village, Toronto                                 11              11
# Dorset Park, Toronto                                        10              10
# Dovercourt Park, Toronto                                     6               6
# Downsview, Toronto                                          10              10
# Dufferin Grove, Toronto                                     50              50
# Earlscourt, Toronto                                         19              19
# East Danforth, Toronto                                       4               4
# Eatonville, Toronto                                         11              11
# Eglinton East, Toronto                                       6               6
# Elia (Jane and Finch), Toronto                              23              23
# Fashion District, Toronto                                   76              76
# Financial District, Toronto                                100             100
# Flemingdon Park, Toronto                                    12              12
# Forest Hill, Toronto                                         4               4
# Fort York/Liberty Village, Toronto                          18              18
# Garden District, Toronto                                    66              66
# Glen Park, Toronto                                           8               8
# Governor's Bridge/Bennington Heights, Toronto                4               4
# Grange Park, Toronto                                       100             100
# Graydon Hall, Toronto                                        4               4
# Guildwood, Toronto                                           5               5
# Harbord Village, Toronto                                    40              40
# Harbourfront / CityPlace, Toronto                           45              45
# Harwood, Toronto                                            14              14
# Henry Farm, Toronto                                          4               4
# High Park North, Toronto                                     5               5
# Highland Creek, Toronto                                      2               2
# Hillcrest, Toronto                                          43              43
# Hoggs Hollow, Toronto                                        9               9
# Humber Heights, Toronto                                      6               6
# Humber Summit, Toronto                                       4               4
# Humber Valley Village, Toronto                               5               5
# Humberlea, Toronto                                           4               4
# Humberwood, Toronto                                          5               5
# Humewood–Cedarvale, Toronto                                  5               5
# Ionview, Toronto                                             3               3
# Islington – Six Points, Toronto                             13              13
# Junction Triangle, Toronto                                  40              40
# Kensington Market, Toronto                                  87              87
# Kingsview Village, Toronto                                   1               1
# L'Amoreaux, Toronto                                          7               7
# Lambton, Toronto                                             3               3
# Lansing, Toronto                                             5               5
# Lawrence Heights, Toronto                                   89              89
# Lawrence Manor, Toronto                                      5               5
# Lawrence Park, Toronto                                      54              54
# Leaside, Toronto                                             4               4
# Ledbury Park, Toronto                                       10              10
# Leslieville, Toronto                                        55              55
# Little Italy, Toronto                                       69              69
# Little Portugal, Toronto                                    37              37
# Long Branch, Toronto                                         9               9
# Lytton Park, Toronto                                         5               5
# Malvern, Toronto                                            15              15
# Maple Leaf, Toronto                                          2               2
# Markland Wood, Toronto                                       4               4
# Maryvale, Toronto                                           20              20
# Milliken, Toronto                                           39              39
# Mimico, Toronto                                              4               4
# Moore Park, Toronto                                          3               3
# Morningside, Toronto                                        12              12
# Mount Dennis, Toronto                                        8               8
# New Toronto, Toronto                                        18              18
# Newtonbrook, Toronto                                         4               4
# Niagara, Toronto                                            53              53
# North York City Centre, Toronto                              3               3
# O'Connor–Parkview, Toronto                                   8               8
# Oakridge, Toronto                                            6               6
# Old East York, Toronto                                       3               3
# Old Mill/Baby Point, Toronto                                 4               4
# Parkdale, Toronto                                           43              43
# Parkway Forest, Toronto                                      6               6
# Parkwoods, Toronto                                          13              13
# Pelmo Park, Toronto                                          3               3
# Playter Estates, Toronto                                    56              56
# Pleasant View, Toronto                                      15              15
# Port Lands, Toronto                                         17              17
# Port Union, Toronto                                          3               3
# Princess Gardens, Toronto                                   85              85
# Regent Park/Trefann Court, Toronto                          30              30
# Richview, Toronto                                            5               5
# Riverdale, Toronto                                          31              31
# Roncesvalles, Toronto                                       38              38
# Rosedale, Toronto                                            5               5
# Rouge Hill, Toronto                                          2               2
# Rouge, Toronto                                               3               3
# Runnymede, Toronto                                          41              41
# Scarborough City Centre, Toronto                             6               6
# Scarborough Junction, Toronto                                4               4
# Scarborough Village, Toronto                                10              10
# Seaton Village, Toronto                                     30              30
# Silverthorn, Toronto                                        14              14
# Smithfield, Toronto                                         19              19
# South Hill, Toronto                                         28              28
# St. James Town, Toronto                                     31              31
# Steeles, Toronto                                             1               1
# Summerhill, Toronto                                         36              36
# Sunnylea, Toronto                                            4               4
# Swansea, Toronto                                             6               6
# Tam O'Shanter – Sullivan, Toronto                            8               8
# The Annex, Toronto                                          43              43
# The Beaches, Toronto                                        49              49
# The Danforth, Toronto                                       30              30
# The Elms, Toronto                                            5               5
# The Junction, Toronto                                       59              59
# The Kingsway, Toronto                                       33              33
# The Queensway, Toronto                                      26              26
# Thistletown, Toronto                                        11              11
# Thorncliffe Park, Toronto                                   25              25
# Toronto Islands, Toronto                                     4               4
# Trinity–Bellwoods, Toronto                                  43              43
# Upper Beaches, Toronto                                       6               6
# Victoria Village, Toronto                                    3               3
# Wallace Emerson, Toronto                                    19              19
# West Hill, Toronto                                          32              32
# West Rouge, Toronto                                          1               1
# Westminster, Toronto                                         4               4
# Westmount, Toronto                                           3               3
# Weston, Toronto                                             16              16
# Wexford, Toronto                                            19              19
# Willowdale, Toronto                                         47              47
# Wilson Heights, Toronto                                      9               9
# Woburn, Toronto                                             21              21
# Wychwood, Toronto                                           53              53
# York Mills, Toronto                                         15              15
# York University Heights, Toronto                            20              20
# Yorkville, Toronto                                         100             100

# %% [markdown]
# #### 3.3. Apply one-hot encoding <a class="anchor" id="3.3"></a>

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")

Toronto_onehot = Toronto_onehot.drop(['Neighborhood'], axis=1)

# add neighborhood column back to dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 


# move neighborhood column to the first column
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.head()

Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
Toronto_grouped
# Out:
#                                       Neighborhood       ATM  \
# 0                               Agincourt, Toronto  0.000000
# 1                               Alderwood, Toronto  0.000000
# 2                          Alexandra Park, Toronto  0.000000
# 3                                 Allenby, Toronto  0.000000
# 4                                Amesbury, Toronto  0.000000
# 5                          Armour Heights, Toronto  0.000000
# 6                                 Banbury, Toronto  0.000000
# 7                          Bathurst Manor, Toronto  0.000000
# 8                     Bay Street Corridor, Toronto  0.000000
# 9                         Bayview Village, Toronto  0.000000
# 10                Bayview Woods – Steeles, Toronto  0.000000
# 11                           Bedford Park, Toronto  0.000000
# 12                                Bendale, Toronto  0.000000
# 13                            Birch Cliff, Toronto  0.000000
# 14                     Bloor West Village, Toronto  0.000000
# 15                        Bracondale Hill, Toronto  0.000000
# 16                                Branson, Toronto  0.000000
# 17                            Bridle Path, Toronto  0.000000
# 18                               Brockton, Toronto  0.000000
# 19                            Cabbagetown, Toronto  0.000000
# 20                           Caribou Park, Toronto  0.000000
# 21                       Carleton Village, Toronto  0.000000
# 22                              Casa Loma, Toronto  0.000000
# 23                             Centennial, Toronto  0.000000
# 24                        Chaplin Estates, Toronto  0.000000
# 25                          Christie Pits, Toronto  0.000000
# 26                   Church and Wellesley, Toronto  0.000000
# 27                               Clairlea, Toronto  0.000000
# 28                             Clairville, Toronto  0.000000
# 29                             Cliffcrest, Toronto  0.000000
# 30                              Cliffside, Toronto  0.000000
# 31                               Corktown, Toronto  0.000000
# 32                          Crescent Town, Toronto  0.000000
# 33                           Cricket Club, Toronto  0.000000
# 34                              Davenport, Toronto  0.000000
# 35                             Davisville, Toronto  0.000000
# 36                              Deer Park, Toronto  0.000000
# 37                     Discovery District, Toronto  0.000000
# 38                              Don Mills, Toronto  0.000000
# 39                     Don Valley Village, Toronto  0.000000
# 40                            Dorset Park, Toronto  0.000000
# 41                        Dovercourt Park, Toronto  0.000000
# 42                              Downsview, Toronto  0.000000
# 43                         Dufferin Grove, Toronto  0.000000
# 44                             Earlscourt, Toronto  0.000000
# 45                          East Danforth, Toronto  0.000000
# 46                             Eatonville, Toronto  0.000000
# 47                          Eglinton East, Toronto  0.000000
# 48                  Elia (Jane and Finch), Toronto  0.000000
# 49                       Fashion District, Toronto  0.000000
# 50                     Financial District, Toronto  0.000000
# 51                        Flemingdon Park, Toronto  0.000000
# 52                            Forest Hill, Toronto  0.000000
# 53              Fort York/Liberty Village, Toronto  0.000000
# 54                        Garden District, Toronto  0.000000
# 55                              Glen Park, Toronto  0.000000
# 56   Governor's Bridge/Bennington Heights, Toronto  0.000000
# 57                            Grange Park, Toronto  0.000000
# 58                           Graydon Hall, Toronto  0.000000
# 59                              Guildwood, Toronto  0.000000
# 60                        Harbord Village, Toronto  0.000000
# 61               Harbourfront / CityPlace, Toronto  0.000000
# 62                                Harwood, Toronto  0.000000
# 63                             Henry Farm, Toronto  0.000000
# 64                        High Park North, Toronto  0.000000
# 65                         Highland Creek, Toronto  0.000000
# 66                              Hillcrest, Toronto  0.000000
# 67                           Hoggs Hollow, Toronto  0.000000
# 68                         Humber Heights, Toronto  0.000000
# 69                          Humber Summit, Toronto  0.000000
# 70                  Humber Valley Village, Toronto  0.000000
# 71                              Humberlea, Toronto  0.000000
# 72                             Humberwood, Toronto  0.000000
# 73                     Humewood–Cedarvale, Toronto  0.000000
# 74                                Ionview, Toronto  0.000000
# 75                 Islington – Six Points, Toronto  0.000000
# 76                      Junction Triangle, Toronto  0.000000
# 77                      Kensington Market, Toronto  0.000000
# 78                      Kingsview Village, Toronto  0.000000
# 79                             L'Amoreaux, Toronto  0.000000
# 80                                Lambton, Toronto  0.000000
# 81                                Lansing, Toronto  0.000000
# 82                       Lawrence Heights, Toronto  0.000000
# 83                         Lawrence Manor, Toronto  0.000000
# 84                          Lawrence Park, Toronto  0.000000
# 85                                Leaside, Toronto  0.000000
# 86                           Ledbury Park, Toronto  0.000000
# 87                            Leslieville, Toronto  0.000000
# 88                           Little Italy, Toronto  0.000000
# 89                        Little Portugal, Toronto  0.000000
# 90                            Long Branch, Toronto  0.000000
# 91                            Lytton Park, Toronto  0.000000
# 92                                Malvern, Toronto  0.000000
# 93                             Maple Leaf, Toronto  0.000000
# 94                          Markland Wood, Toronto  0.000000
# 95                               Maryvale, Toronto  0.000000
# 96                               Milliken, Toronto  0.000000
# 97                                 Mimico, Toronto  0.000000
# 98                             Moore Park, Toronto  0.000000
# 99                            Morningside, Toronto  0.000000
# 100                          Mount Dennis, Toronto  0.000000
# 101                           New Toronto, Toronto  0.000000
# 102                           Newtonbrook, Toronto  0.000000
# 103                               Niagara, Toronto  0.000000
# 104                North York City Centre, Toronto  0.000000
# 105                     O'Connor–Parkview, Toronto  0.000000
# 106                              Oakridge, Toronto  0.000000
# 107                         Old East York, Toronto  0.000000
# 108                   Old Mill/Baby Point, Toronto  0.000000
# 109                              Parkdale, Toronto  0.000000
# 110                        Parkway Forest, Toronto  0.000000
# 111                             Parkwoods, Toronto  0.076923
# 112                            Pelmo Park, Toronto  0.000000
# 113                       Playter Estates, Toronto  0.000000
# 114                         Pleasant View, Toronto  0.000000
# 115                            Port Lands, Toronto  0.000000
# 116                            Port Union, Toronto  0.000000
# 117                      Princess Gardens, Toronto  0.000000
# 118             Regent Park/Trefann Court, Toronto  0.000000
# 119                              Richview, Toronto  0.000000
# 120                             Riverdale, Toronto  0.000000
# 121                          Roncesvalles, Toronto  0.000000
# 122                              Rosedale, Toronto  0.000000
# 123                            Rouge Hill, Toronto  0.000000
# 124                                 Rouge, Toronto  0.000000
# 125                             Runnymede, Toronto  0.000000
# 126               Scarborough City Centre, Toronto  0.000000
# 127                  Scarborough Junction, Toronto  0.000000
# 128                   Scarborough Village, Toronto  0.000000
# 129                        Seaton Village, Toronto  0.000000
# 130                           Silverthorn, Toronto  0.000000
# 131                            Smithfield, Toronto  0.000000
# 132                            South Hill, Toronto  0.000000
# 133                        St. James Town, Toronto  0.000000
# 134                               Steeles, Toronto  0.000000
# 135                            Summerhill, Toronto  0.000000
# %%
num_top_venues = 5

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# Sort the venues in descending order 
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]


# ==================================================================================================================


num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
Toronto_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
Toronto_neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']
for ind in np.arange(Toronto_grouped.shape[0]):
    Toronto_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

Toronto_neighborhoods_venues_sorted.head()
# Out:
# ----Agincourt, Toronto----
#                   venue  freq
# 0    Chinese Restaurant  0.25
# 1      Asian Restaurant  0.08
# 2          Intersection  0.08
# 3            Food Court  0.08
# 4  Cantonese Restaurant  0.08
#
#
# ----Alderwood, Toronto----
#             venue  freq
# 0     Pizza Place  0.29
# 1             Gym  0.14
# 2      Playground  0.14
# 3             Pub  0.14
# 4  Sandwich Place  0.14
#
#
# ----Alexandra Park, Toronto----
#                     venue  freq
# 0                     Bar  0.11
# 1  Furniture / Home Store  0.05
# 2                    Café  0.05
# 3    Caribbean Restaurant  0.04
# 4     Arts & Crafts Store  0.02
#
#
# ----Allenby, Toronto----
#                   venue  freq
# 0         Big Box Store  0.14
# 1  Fast Food Restaurant  0.14
# 2    African Restaurant  0.14
# 3          Intersection  0.14
# 4     Fish & Chips Shop  0.14
#
#
# ----Amesbury, Toronto----
#           venue  freq
# 0          Bank  0.17
# 1   Coffee Shop  0.17
# 2  Intersection  0.17
# 3          Park  0.17
# 4   Gas Station  0.17
#
#
# ----Armour Heights, Toronto----
#              venue  freq
# 0         Pharmacy  0.33
# 1    Deli / Bodega  0.33
# 2           Market  0.33
# 3              ATM  0.00
# 4  Organic Grocery  0.00
#
#
# ----Banbury, Toronto----
#               venue  freq
# 0       Coffee Shop  0.17
# 1  Botanical Garden  0.17
# 2      Intersection  0.17
# 3              Park  0.17
# 4       Gas Station  0.17
#
#
# ----Bathurst Manor, Toronto----
#                venue  freq
# 0  Convenience Store  0.25
# 1               Park  0.25
# 2         Playground  0.25
# 3     Baseball Field  0.25
# 4         Non-Profit  0.00
#
#
# ----Bay Street Corridor, Toronto----
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1            Boutique  0.05
# 2                Café  0.05
# 3      Clothing Store  0.04
# 4         Coffee Shop  0.04
#
#
# ----Bayview Village, Toronto----
#                   venue  freq
# 0                  Bank  0.15
# 1        Breakfast Spot  0.08
# 2             Pet Store  0.08
# 3  Outdoor Supply Store  0.08
# 4           Fish Market  0.08
#
#
# ----Bayview Woods – Steeles, Toronto----
#                venue  freq
# 0            Dog Run   1.0
# 1                ATM   0.0
# 2  Outdoor Sculpture   0.0
# 3    Organic Grocery   0.0
# 4       Optical Shop   0.0
#
#
# ----Bedford Park, Toronto----
#                   venue  freq
# 0   Rental Car Location   0.5
# 1  Gym / Fitness Center   0.5
# 2             Nightclub   0.0
# 3  Other Great Outdoors   0.0
# 4       Organic Grocery   0.0
#
#
# ----Bendale, Toronto----
#                   venue  freq
# 0  Fast Food Restaurant  0.14
# 1          Tennis Court  0.14
# 2         Grocery Store  0.14
# 3      Department Store  0.14
# 4          Optical Shop  0.14
#
#
# ----Birch Cliff, Toronto----
#                    venue  freq
# 0        College Stadium  0.25
# 1           Skating Rink  0.25
# 2                   Café  0.25
# 3  General Entertainment  0.25
# 4             Non-Profit  0.00
#
#
# ----Bloor West Village, Toronto----
#               venue  freq
# 0              Café  0.08
# 1       Coffee Shop  0.08
# 2       Pizza Place  0.08
# 3               Pub  0.05
# 4  Sushi Restaurant  0.05
#
#
# ----Bracondale Hill, Toronto----
#          venue  freq
# 0         Park  0.33
# 1       Bakery  0.17
# 2  Art Gallery  0.17
# 3  Coffee Shop  0.17
# 4          Bar  0.17
#
#
# ----Branson, Toronto----
#             venue  freq
# 0     Coffee Shop  0.12
# 1    Intersection  0.12
# 2     Pizza Place  0.12
# 3  Sandwich Place  0.12
# 4    Skating Rink  0.12
#
#
# ----Bridle Path, Toronto----
#                   venue  freq
# 0           Music Venue   1.0
# 1                   ATM   0.0
# 2            Non-Profit   0.0
# 3  Other Great Outdoors   0.0
# 4       Organic Grocery   0.0
#
#
# ----Brockton, Toronto----
#                    venue  freq
# 0                    Bar  0.17
# 1          Grocery Store  0.11
# 2                   Park  0.11
# 3  Vietnamese Restaurant  0.11
# 4  Portuguese Restaurant  0.06
#
#
# ----Cabbagetown, Toronto----
#                 venue  freq
# 0          Restaurant  0.08
# 1         Coffee Shop  0.06
# 2   Indian Restaurant  0.06
# 3                Café  0.06
# 4  Italian Restaurant  0.04
#
#
# ----Caribou Park, Toronto----
#                        venue  freq
# 0           Department Store  0.17
# 1             Breakfast Spot  0.08
# 2               Liquor Store  0.08
# 3                       Bank  0.08
# 4  Middle Eastern Restaurant  0.08
#
#
# ----Carleton Village, Toronto----
#                venue  freq
# 0               Park  0.25
# 1        Coffee Shop  0.25
# 2            Dog Run  0.25
# 3      Jewelry Store  0.25
# 4  Outdoor Sculpture  0.00
#
#
# ----Casa Loma, Toronto----
#                        venue  freq
# 0             Sandwich Place  0.13
# 1             History Museum  0.13
# 2                       Café  0.09
# 3                Coffee Shop  0.09
# 4  Middle Eastern Restaurant  0.04
#
#
# ----Centennial, Toronto----
#              venue  freq
# 0              Bar   0.5
# 1             Park   0.5
# 2              ATM   0.0
# 3       Non-Profit   0.0
# 4  Organic Grocery   0.0
#
#
# ----Chaplin Estates, Toronto----
#                  venue  freq
# 0   Italian Restaurant  0.17
# 1          Gas Station  0.06
# 2  Arts & Crafts Store  0.06
# 3       Breakfast Spot  0.06
# 4     Sushi Restaurant  0.06
#
#
# ----Christie Pits, Toronto----
#                venue  freq
# 0  Indian Restaurant  0.17
# 1               Café  0.17
# 2      Grocery Store  0.17
# 3         Restaurant  0.08
# 4          Nightclub  0.08
#
#
# ----Church and Wellesley, Toronto----
#                   venue  freq
# 0           Coffee Shop  0.13
# 1           Pizza Place  0.06
# 2         Grocery Store  0.06
# 3    Italian Restaurant  0.03
# 4  Caribbean Restaurant  0.03
#
#
# ----Clairlea, Toronto----
#                venue  freq
# 0      Grocery Store  0.14
# 1         Restaurant  0.14
# 2     Ice Cream Shop  0.14
# 3  Convenience Store  0.14
# 4     Sandwich Place  0.14
#
#
# ----Clairville, Toronto----
#                   venue  freq
# 0               Airport   0.6
# 1      Airport Terminal   0.4
# 2                   ATM   0.0
# 3            Non-Profit   0.0
# 4  Other Great Outdoors   0.0
#
#
# ----Cliffcrest, Toronto----
#             venue  freq
# 0  Ice Cream Shop   0.4
# 1     Pizza Place   0.2
# 2     Auto Garage   0.2
# 3      Restaurant   0.2
# 4       Nightclub   0.0
#
#
# ----Cliffside, Toronto----
#             venue  freq
# 0   Grocery Store  0.14
# 1     Coffee Shop  0.14
# 2  Breakfast Spot  0.14
# 3     Pizza Place  0.14
# 4             Pub  0.14
#
#
# ----Corktown, Toronto----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                 Park  0.11
# 2       Breakfast Spot  0.06
# 3                  Pub  0.06
# 4  Distribution Center  0.03
#
#
# ----Crescent Town, Toronto----
#                venue  freq
# 0  Convenience Store  0.25
# 1               Park  0.25
# 2      Metro Station  0.25
# 3        Golf Course  0.25
# 4         Non-Profit  0.00
#
#
# ----Cricket Club, Toronto----
#                venue  freq
# 0         Restaurant   0.1
# 1        Coffee Shop   0.1
# 2        Sports Club   0.1
# 3       Intersection   0.1
# 4  Indian Restaurant   0.1
#
#
# ----Davenport, Toronto----
#                venue  freq
# 0               Park  0.17
# 1  Convenience Store  0.17
# 2         Playground  0.17
# 3        Music Venue  0.17
# 4            Dog Run  0.17
#
#
# ----Davisville, Toronto----
#                 venue  freq
# 0    Sushi Restaurant  0.10
# 1  Italian Restaurant  0.10
# 2         Coffee Shop  0.08
# 3                Café  0.05
# 4   Convenience Store  0.05
#
#
# ----Deer Park, Toronto----
#                 venue  freq
# 0         Coffee Shop  0.13
# 1  Italian Restaurant  0.09
# 2       Grocery Store  0.05
# 3    Sushi Restaurant  0.05
# 4     Thai Restaurant  0.05
#
#
# ----Discovery District, Toronto----
#                  venue  freq
# 0          Coffee Shop  0.18
# 1                 Café  0.09
# 2          Art Gallery  0.05
# 3  Japanese Restaurant  0.03
# 4         Dessert Shop  0.03
#
#
# ----Don Mills, Toronto----
#                   venue  freq
# 0        Clothing Store  0.14
# 1           Coffee Shop  0.08
# 2  Fast Food Restaurant  0.05
# 3   Japanese Restaurant  0.05
# 4            Restaurant  0.05
#
#
# ----Don Valley Village, Toronto----
#                   venue  freq
# 0                  Bank  0.18
# 1        Sandwich Place  0.18
# 2           Coffee Shop  0.18
# 3           Pizza Place  0.09
# 4  Cantonese Restaurant  0.09
#
#
# ----Dorset Park, Toronto----
#                 venue  freq
# 0  Chinese Restaurant   0.1
# 1    Asian Restaurant   0.1
# 2   Indian Restaurant   0.1
# 3   Accessories Store   0.1
# 4       Bowling Alley   0.1
#
#
# ----Dovercourt Park, Toronto----
#                  venue  freq
# 0                  Bar  0.17
# 1                 Park  0.17
# 2                 Café  0.17
# 3  Rental Car Location  0.17
# 4             Bus Line  0.17
#
#
# ----Downsview, Toronto----
#                     venue  freq
# 0  Furniture / Home Store   0.1
# 1             Coffee Shop   0.1
# 2             Gas Station   0.1
# 3           Metro Station   0.1
# 4             Men's Store   0.1
#
#
# ----Dufferin Grove, Toronto----
#                 venue  freq
# 0                 Bar  0.10
# 1         Coffee Shop  0.10
# 2  Italian Restaurant  0.08
# 3          Restaurant  0.08
# 4                Café  0.06
#
#
# ----Earlscourt, Toronto----
#                   venue  freq
# 0    Italian Restaurant  0.21
# 1                  Café  0.11
# 2                Bakery  0.11
# 3  Brazilian Restaurant  0.05
# 4               Dog Run  0.05
#
#
# ----East Danforth, Toronto----
#                  venue  freq
# 0    Convenience Store  0.25
# 1                 Park  0.25
# 2        Metro Station  0.25
# 3  Filipino Restaurant  0.25
# 4         Noodle House  0.00
#
#
# ----Eatonville, Toronto----
#                 venue  freq
# 0             Theater  0.09
# 1  Mexican Restaurant  0.09
# 2                Bank  0.09
# 3       Grocery Store  0.09
# 4                Park  0.09
#
#
# ----Eglinton East, Toronto----
#                venue  freq
# 0     Ice Cream Shop  0.33
# 1         Restaurant  0.17
# 2  Indian Restaurant  0.17
# 3     Sandwich Place  0.17
# 4      Train Station  0.17
#
#
# ----Elia (Jane and Finch), Toronto----
#                   venue  freq
# 0  Fast Food Restaurant  0.09
# 1           Pizza Place  0.09
# 2         Shopping Mall  0.09
# 3         Grocery Store  0.09
# 4        Discount Store  0.09
#
#
# ----Fashion District, Toronto----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1          Restaurant  0.07
# 2  Italian Restaurant  0.05
# 3                Café  0.04
# 4               Hotel  0.04
#
#
# ----Financial District, Toronto----
#          venue  freq
# 0  Coffee Shop  0.12
# 1        Hotel  0.08
# 2         Café  0.06
# 3   Restaurant  0.05
# 4          Gym  0.04
#
#
# ----Flemingdon Park, Toronto----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1             Nightclub  0.08
# 2                   Gym  0.08
# 3  Gym / Fitness Center  0.08
# 4        Science Museum  0.08
#
#
# ----Forest Hill, Toronto----
#                  venue  freq
# 0                 Bank  0.25
# 1           Playground  0.25
# 2                 Park  0.25
# 3  Arts & Crafts Store  0.25
# 4         Noodle House  0.00
#
#
# ----Fort York/Liberty Village, Toronto----
#            venue  freq
# 0           Park  0.17
# 1          Trail  0.11
# 2          Track  0.06
# 3  Historic Site  0.06
# 4            Gym  0.06
#
#
# ----Garden District, Toronto----
#             venue  freq
# 0  Clothing Store  0.08
# 1     Coffee Shop  0.08
# 2           Hotel  0.06
# 3  Cosmetics Shop  0.05
# 4    Burger Joint  0.05
#
#
# ----Glen Park, Toronto----
#               venue  freq
# 0            Bakery  0.12
# 1  Asian Restaurant  0.12
# 2        Playground  0.12
# 3     Grocery Store  0.12
# 4       Pizza Place  0.12
#
#
# ----Governor's Bridge/Bennington Heights, Toronto----
#              venue  freq
# 0             Park  0.75
# 1            Trail  0.25
# 2              ATM  0.00
# 3       Non-Profit  0.00
# 4  Organic Grocery  0.00
#
#
# ----Grange Park, Toronto----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1                 Café  0.06
# 2   Chinese Restaurant  0.03
# 3  Japanese Restaurant  0.03
# 4       Clothing Store  0.03
#
#
# ----Graydon Hall, Toronto----
#          venue  freq
# 0     Bus Line  0.25
# 1   Playground  0.25
# 2  Event Space  0.25
# 3     Bus Stop  0.25
# 4   Non-Profit  0.00
#
#
# ----Guildwood, Toronto----
#               venue  freq
# 0     Train Station   0.4
# 1  Storage Facility   0.2
# 2    Baseball Field   0.2
# 3               Spa   0.2
# 4               ATM   0.0
#
#
# ----Harbord Village, Toronto----
#                venue  freq
# 0  Korean Restaurant  0.08
# 1     Ice Cream Shop  0.05
# 2         Restaurant  0.05
# 3                Bar  0.05
# 4               Café  0.05
#
#
# ----Harbourfront / CityPlace, Toronto----
#               venue  freq
# 0             Hotel  0.09
# 1       Coffee Shop  0.09
# 2  Baseball Stadium  0.07
# 3               Bar  0.04
# 4           Theater  0.04
#
#
# ----Harwood, Toronto----
#                  venue  freq
# 0              Brewery  0.14
# 1            BBQ Joint  0.14
# 2  Sporting Goods Shop  0.07
# 3          Coffee Shop  0.07
# 4         Gourmet Shop  0.07
#
#
# ----Henry Farm, Toronto----
#           venue  freq
# 0        Lawyer  0.25
# 1  Tennis Court  0.25
# 2          Park  0.25
# 3  Intersection  0.25
# 4    Non-Profit  0.00
#
#
# ----High Park North, Toronto----
#             venue  freq
# 0            Park   0.4
# 1  Baseball Field   0.2
# 2    Tennis Court   0.2
# 3  Mattress Store   0.2
# 4             ATM   0.0
#
#
# ----Highland Creek, Toronto----
#                   venue  freq
# 0           IT Services   0.5
# 1                   ATM   0.0
# 2  Other Great Outdoors   0.0
# 3       Organic Grocery   0.0
# 4          Optical Shop   0.0
#
#
# ----Hillcrest, Toronto----
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1          Restaurant  0.05
# 2  Mexican Restaurant  0.05
# 3                Café  0.05
# 4    Sushi Restaurant  0.05
#
#
# ----Hoggs Hollow, Toronto----
#                  venue  freq
# 0                  Gym  0.22
# 1          Coffee Shop  0.22
# 2    Indian Restaurant  0.11
# 3                  Pub  0.11
# 4  Japanese Restaurant  0.11
#
#
# ----Humber Heights, Toronto----
#                  venue  freq
# 0  Fried Chicken Joint  0.17
# 1       Breakfast Spot  0.17
# 2         Skating Rink  0.17
# 3          Gas Station  0.17
# 4                Diner  0.17
#
#
# ----Humber Summit, Toronto----
#          venue  freq
# 0         Park  0.25
# 1  Flower Shop  0.25
# 2       Bakery  0.25
# 3     Pharmacy  0.25
# 4          ATM  0.00
#
#
# ----Humber Valley Village, Toronto----
#                venue  freq
# 0  Convenience Store   0.2
# 1               Park   0.2
# 2       Skating Rink   0.2
# 3           Bus Stop   0.2
# 4             Bakery   0.2
#
#
# ----Humberlea, Toronto----
#                venue  freq
# 0  Convenience Store  0.25
# 1     Baseball Field  0.25
# 2        Gas Station  0.25
# 3             Bakery  0.25
# 4                ATM  0.00
#
#
# ----Humberwood, Toronto----
#                         venue  freq
# 0                 Golf Course   0.4
# 1           Mobile Phone Shop   0.2
# 2  Construction & Landscaping   0.2
# 3            Hakka Restaurant   0.2
# 4                  Non-Profit   0.0
#
#
# ----Humewood–Cedarvale, Toronto----
#                venue  freq
# 0       Hockey Arena   0.2
# 1  Convenience Store   0.2
# 2              Field   0.2
# 3              Trail   0.2
# 4     Soccer Stadium   0.2
#
#
# ----Ionview, Toronto----
#            venue  freq
# 0  Metro Station  0.33
# 1  Deli / Bodega  0.33
# 2           Park  0.33
# 3            ATM  0.00
# 4     Non-Profit  0.00
#
#
# ----Islington – Six Points, Toronto----
#                 venue  freq
# 0    Sushi Restaurant  0.15
# 1      Sandwich Place  0.08
# 2                 Pub  0.08
# 3  Turkish Restaurant  0.08
# 4   Fish & Chips Shop  0.08
#
#
# ----Junction Triangle, Toronto----
#                     venue  freq
# 0                    Café  0.10
# 1             Pizza Place  0.05
# 2  Thrift / Vintage Store  0.05
# 3                     Pub  0.05
# 4          Clothing Store  0.05
#
#
# ----Kensington Market, Toronto----
#                            venue  freq
# 0                           Café  0.08
# 1                    Coffee Shop  0.06
# 2                            Bar  0.05
# 3             Mexican Restaurant  0.05
# 4  Vegetarian / Vegan Restaurant  0.05
#
#
# ----Kingsview Village, Toronto----
#                venue  freq
# 0               Park   1.0
# 1                ATM   0.0
# 2  Outdoor Sculpture   0.0
# 3    Organic Grocery   0.0
# 4       Optical Shop   0.0
#
#
# ----L'Amoreaux, Toronto----
#                   venue  freq
# 0    Chinese Restaurant  0.29
# 1  Caribbean Restaurant  0.14
# 2         Shopping Mall  0.14
# 3    Athletics & Sports  0.14
# 4              Bus Stop  0.14
#
#
# ----Lambton, Toronto----
#                  venue  freq
# 0               Bakery  0.33
# 1  Sporting Goods Shop  0.33
# 2        Grocery Store  0.33
# 3           Non-Profit  0.00
# 4      Organic Grocery  0.00
#
#
# ----Lansing, Toronto----
#               venue  freq
# 0       IT Services   0.2
# 1               Spa   0.2
# 2  Business Service   0.2
# 3      Home Service   0.2
# 4        Playground   0.2
#
#
# ----Lawrence Heights, Toronto----
#                     venue  freq
# 0          Clothing Store  0.17
# 1             Coffee Shop  0.06
# 2              Restaurant  0.04
# 3           Women's Store  0.03
# 4  Furniture / Home Store  0.03
#
#
# ----Lawrence Manor, Toronto----
#                venue  freq
# 0  Electronics Store   0.2
# 1         Kids Store   0.2
# 2               Park   0.2
# 3    Doctor's Office   0.2
# 4               Bank   0.2
#
#
# ----Lawrence Park, Toronto----
#                   venue  freq
# 0    Italian Restaurant  0.07
# 1      Sushi Restaurant  0.07
# 2                Bakery  0.06
# 3           Coffee Shop  0.06
# 4  Fast Food Restaurant  0.04
#
#
# ----Leaside, Toronto----
#                  venue  freq
# 0    Convenience Store  0.25
# 1                 Park  0.25
# 2       Sandwich Place  0.25
# 3  Japanese Restaurant  0.25
# 4         Noodle House  0.00
#
#
# ----Ledbury Park, Toronto----
#                 venue  freq
# 0              Bakery   0.1
# 1                Park   0.1
# 2         Wings Joint   0.1
# 3           Wine Shop   0.1
# 4  Italian Restaurant   0.1
#
#
# ----Leslieville, Toronto----
#                   venue  freq
# 0                Bakery  0.07
# 1               Brewery  0.05
# 2           Coffee Shop  0.05
# 3                 Diner  0.05
# 4  Fast Food Restaurant  0.04
#
#
# ----Little Italy, Toronto----
#                 venue  freq
# 0  Italian Restaurant  0.10
# 1                 Bar  0.07
# 2                Café  0.06
# 3      Sandwich Place  0.04
# 4    Tapas Restaurant  0.03
#
#
# ----Little Portugal, Toronto----
#                venue  freq
# 0                Bar  0.14
# 1               Café  0.11
# 2        Coffee Shop  0.08
# 3       Cocktail Bar  0.05
# 4  Korean Restaurant  0.05
#
#
# ----Long Branch, Toronto----
#                 venue  freq
# 0  Seafood Restaurant  0.11
# 1       Burrito Place  0.11
# 2               Trail  0.11
# 3                Park  0.11
# 4                Café  0.11
#
#
# ----Lytton Park, Toronto----
#                 venue  freq
# 0          Playground   0.2
# 1              Garden   0.2
# 2                 Spa   0.2
# 3  Photography Studio   0.2
# 4                 Gym   0.2
#
#
# ----Malvern, Toronto----
#                   venue  freq
# 0  Fast Food Restaurant  0.20
# 1           Pizza Place  0.13
# 2              Pharmacy  0.13
# 3                  Bank  0.07
# 4     Convenience Store  0.07
#
#
# ----Maple Leaf, Toronto----
#                   venue  freq
# 0                Bakery   0.5
# 1      Basketball Court   0.5
# 2     Outdoor Sculpture   0.0
# 3  Other Great Outdoors   0.0
# 4       Organic Grocery   0.0
#
#
# ----Markland Wood, Toronto----
#             venue  freq
# 0  Baseball Field  0.25
# 1            Park  0.25
# 2     Golf Course  0.25
# 3       Piano Bar  0.25
# 4             ATM  0.00
#
#
# ----Maryvale, Toronto----
#                venue  freq
# 0        Coffee Shop  0.10
# 1           Bus Line  0.05
# 2  Electronics Store  0.05
# 3   Hakka Restaurant  0.05
# 4                Spa  0.05
#
#
# ----Milliken, Toronto----
#                  venue  freq
# 0   Chinese Restaurant  0.21
# 1               Bakery  0.08
# 2  Japanese Restaurant  0.05
# 3         Intersection  0.05
# 4            Pet Store  0.05
#
#
# ----Mimico, Toronto----
#           venue  freq
# 0   Yoga Studio  0.25
# 1  Skating Rink  0.25
# 2           Bar  0.25
# 3        Bakery  0.25
# 4        Museum  0.00
#
#
# ----Moore Park, Toronto----
#                      venue  freq
# 0        Convenience Store  0.33
# 1                     Park  0.33
# 2                      Gym  0.33
# 3            Moving Target  0.00
# 4  North Indian Restaurant  0.00
#
#
# ----Morningside, Toronto----
#             venue  freq
# 0        Pharmacy  0.17
# 1            Park  0.17
# 2     Coffee Shop  0.17
# 3  Discount Store  0.08
# 4  Sandwich Place  0.08
#
#
# ----Mount Dennis, Toronto----
#                     venue  freq
# 0  Furniture / Home Store  0.25
# 1             Coffee Shop  0.25
# 2           Grocery Store  0.12
# 3            Tennis Court  0.12
# 4             Pizza Place  0.12
#
#
# ----New Toronto, Toronto----
#                 venue  freq
# 0            Pharmacy  0.11
# 1                Café  0.11
# 2   Indian Restaurant  0.06
# 3         Flower Shop  0.06
# 4  Mexican Restaurant  0.06
#
#
# ----Newtonbrook, Toronto----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.25
# 1          Korean Restaurant  0.25
# 2           Greek Restaurant  0.25
# 3            Thai Restaurant  0.25
# 4              Moving Target  0.00
#
#
# ----Niagara, Toronto----
#           venue  freq
# 0   Yoga Studio  0.06
# 1        Bakery  0.06
# 2   Pizza Place  0.06
# 3  Dessert Shop  0.06
# 4          Café  0.06
#
#
# ----North York City Centre, Toronto----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.33
# 1   Mediterranean Restaurant  0.33
# 2                Coffee Shop  0.33
# 3                        ATM  0.00
# 4                 Non-Profit  0.00
#
#
# ----O'Connor–Parkview, Toronto----
#           venue  freq
# 0      Pharmacy  0.25
# 1   Pizza Place  0.25
# 2   Flea Market  0.12
# 3  Intersection  0.12
# 4     Gastropub  0.12
#
#
# ----Oakridge, Toronto----
#                venue  freq
# 0               Park  0.17
# 1           Bus Stop  0.17
# 2     Ice Cream Shop  0.17
# 3  Convenience Store  0.17
# 4       Dessert Shop  0.17
#
#
# ----Old East York, Toronto----
#              venue  freq
# 0      Coffee Shop  0.33
# 1            Trail  0.33
# 2       Food Court  0.33
# 3              ATM  0.00
# 4  Organic Grocery  0.00
#
#
# ----Old Mill/Baby Point, Toronto----
#              venue  freq
# 0             Park  0.75
# 1            River  0.25
# 2              ATM  0.00
# 3  Organic Grocery  0.00
# 4     Optical Shop  0.00
#
#
# ----Parkdale, Toronto----
#                 venue  freq
# 0  Tibetan Restaurant  0.07
# 1              Bakery  0.05
# 2          Restaurant  0.05
# 3            Pharmacy  0.05
# 4               Diner  0.05
#
#
# ----Parkway Forest, Toronto----
#                  venue  freq
# 0               Bakery  0.17
# 1        Grocery Store  0.17
# 2                 Park  0.17
# 3       Sandwich Place  0.17
# 4  Japanese Restaurant  0.17
#
#
# ----Parkwoods, Toronto----
#            venue  freq
# 0            ATM  0.08
# 1       Pharmacy  0.08
# 2    Gas Station  0.08
# 3       Bus Line  0.08
# 4  Shopping Mall  0.08
#
#
# ----Pelmo Park, Toronto----
#                   venue  freq
# 0           Coffee Shop  0.33
# 1                  Park  0.33
# 2          Intersection  0.33
# 3                   ATM  0.00
# 4  Other Great Outdoors  0.00
#
#
# ----Playter Estates, Toronto----
#               venue  freq
# 0  Greek Restaurant  0.11
# 1               Pub  0.07
# 2    Ice Cream Shop  0.04
# 3              Café  0.04
# 4       Coffee Shop  0.04
#
#
# ----Pleasant View, Toronto----
#                venue  freq
# 0               Bank  0.07
# 1  Convenience Store  0.07
# 2      Shopping Mall  0.07
# 3       Skating Rink  0.07
# 4             Bakery  0.07
#
#
# ----Port Lands, Toronto----
#                 venue  freq
# 0     Harbor / Marina  0.12
# 1              Circus  0.12
# 2  Athletics & Sports  0.06
# 3         Music Venue  0.06
# 4           Nightclub  0.06
#
#
# ----Port Union, Toronto----
#                venue  freq
# 0               Park   1.0
# 1                ATM   0.0
# 2  Outdoor Sculpture   0.0
# 3    Organic Grocery   0.0
# 4       Optical Shop   0.0
#
#
# ----Princess Gardens, Toronto----
#               venue  freq
# 0       Coffee Shop  0.09
# 1       Pizza Place  0.06
# 2          Aquarium  0.06
# 3             Hotel  0.05
# 4  Baseball Stadium  0.05
#
#
# ----Regent Park/Trefann Court, Toronto----
#                 venue  freq
# 0          Restaurant  0.10
# 1            Pharmacy  0.07
# 2       Grocery Store  0.07
# 3         Yoga Studio  0.03
# 4  Chinese Restaurant  0.03
#
#
# ----Richview, Toronto----
#              venue  freq
# 0         Pharmacy   0.2
# 1   Baseball Field   0.2
# 2  Supplement Shop   0.2
# 3       Shoe Store   0.2
# 4         Bus Stop   0.2
#
#
# ----Riverdale, Toronto----
#                    venue  freq
# 0  Vietnamese Restaurant  0.16
# 1     Chinese Restaurant  0.10
# 2   Fast Food Restaurant  0.06
# 3                 Bakery  0.06
# 4            Bridal Shop  0.06
#
#
# ----Roncesvalles, Toronto----
#             venue  freq
# 0            Café  0.08
# 1  Breakfast Spot  0.05
# 2      Restaurant  0.05
# 3    Gourmet Shop  0.05
# 4       Bookstore  0.05
#
#
# ----Rosedale, Toronto----
#                         venue  freq
# 0                        Park   0.4
# 1  Construction & Landscaping   0.2
# 2                  Playground   0.2
# 3                  Bike Trail   0.2
# 4                         ATM   0.0
#
#
# ----Rouge Hill, Toronto----
#              venue  freq
# 0    Train Station   0.5
# 1         Bus Line   0.5
# 2              ATM   0.0
# 3        Nightclub   0.0
# 4  Organic Grocery   0.0
#
#
# ----Rouge, Toronto----
#                   venue  freq
# 0  Caribbean Restaurant  0.33
# 1                  Park  0.33
# 2  Fast Food Restaurant  0.33
# 3                   ATM  0.00
# 4  Other Great Outdoors  0.00
#
#
# ----Runnymede, Toronto----
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.10
# 2       Bakery  0.07
# 3  Pizza Place  0.05
# 4         Bank  0.05
#
#
# ----Scarborough City Centre, Toronto----
#             venue  freq
# 0    Soccer Field  0.17
# 1     Pizza Place  0.17
# 2      Sports Bar  0.17
# 3  Sandwich Place  0.17
# 4   Train Station  0.17
#
#
# ----Scarborough Junction, Toronto----
#             venue  freq
# 0      Restaurant  0.25
# 1  Sandwich Place  0.25
# 2   Train Station  0.25
# 3    Soccer Field  0.25
# 4             ATM  0.00
#
#
# ----Scarborough Village, Toronto----
#                   venue  freq
# 0           Coffee Shop   0.2
# 1    Chinese Restaurant   0.1
# 2           Supermarket   0.1
# 3  Fast Food Restaurant   0.1
# 4         Shopping Mall   0.1
#
#
# ----Seaton Village, Toronto----
#                            venue  freq
# 0                  Grocery Store  0.10
# 1                          Diner  0.07
# 2                    Coffee Shop  0.07
# 3  Vegetarian / Vegan Restaurant  0.07
# 4                           Café  0.07
#
#
# ----Silverthorn, Toronto----
#                        venue  freq
# 0                     Bakery  0.14
# 1                Gas Station  0.07
# 2  Latin American Restaurant  0.07
# 3                Pizza Place  0.07
# 4             Discount Store  0.07
#
#
# ----Smithfield, Toronto----
#             venue  freq
# 0     Coffee Shop  0.16
# 1            Bank  0.11
# 2   Grocery Store  0.05
# 3       Pet Store  0.05
# 4  Sandwich Place  0.05
#
#
# ----South Hill, Toronto----
#             venue  freq
# 0  History Museum  0.11
# 1  Sandwich Place  0.11
# 2            Café  0.07
# 3     Coffee Shop  0.07
# 4   Garden Center  0.04
#
#
# ----St. James Town, Toronto----
#            venue  freq
# 0    Coffee Shop  0.16
# 1    Pizza Place  0.10
# 2  Grocery Store  0.06
# 3           Café  0.06
# 4          Diner  0.03
#
#
# ----Steeles, Toronto----
#              venue  freq
# 0       Playground   1.0
# 1              ATM   0.0
# 2        Nightclub   0.0
# 3  Organic Grocery   0.0
# 4     Optical Shop   0.0
#
#
# ----Summerhill, Toronto----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1                 Spa  0.06
# 2    Sushi Restaurant  0.06
# 3                 Gym  0.06
# 4                Café  0.06
#
#
# ----Sunnylea, Toronto----
#                         venue  freq
# 0        Gym / Fitness Center  0.25
# 1  Construction & Landscaping  0.25
# 2                  Playground  0.25
# 3               Poutine Place  0.25
# 4                  Non-Profit  0.00
#
#
# ----Swansea, Toronto----
#                         venue  freq
# 0                        Park  0.33
# 1                 Social Club  0.17
# 2                  Restaurant  0.17
# 3  Construction & Landscaping  0.17
# 4              Pilates Studio  0.17
#
#
# ----Tam O'Shanter – Sullivan, Toronto----
#                 venue  freq
# 0     Thai Restaurant  0.12
# 1        Intersection  0.12
# 2      Sandwich Place  0.12
# 3  Italian Restaurant  0.12
# 4         Gas Station  0.12
#
#
# ----The Annex, Toronto----
#                venue  freq
# 0        Pizza Place  0.09
# 1               Park  0.07
# 2  Indian Restaurant  0.05
# 3    Thai Restaurant  0.05
# 4      Grocery Store  0.05
#
#
# ----The Beaches, Toronto----
#                 venue  freq
# 0               Beach  0.06
# 1                 Pub  0.04
# 2                 Bar  0.04
# 3  Salon / Barbershop  0.04
# 4              Bakery  0.04
#
#
# ----The Danforth, Toronto----
#            venue  freq
# 0    Coffee Shop  0.10
# 1  Grocery Store  0.10
# 2       Bus Line  0.07
# 3       Pharmacy  0.07
# 4           Bank  0.03
#
#
# ----The Elms, Toronto----
#            venue  freq
# 0   Soccer Field   0.2
# 1  Grocery Store   0.2
# 2    Pizza Place   0.2
# 3   Skating Rink   0.2
# 4    Gas Station   0.2
#
#
# ----The Junction, Toronto----
#                 venue  freq
# 0     Thai Restaurant  0.05
# 1  Italian Restaurant  0.05
# 2                 Bar  0.05
# 3         Coffee Shop  0.05
# 4                Café  0.05
#
#
# ----The Kingsway, Toronto----
#               venue  freq
# 0       Coffee Shop  0.09
# 1    Breakfast Spot  0.06
# 2      Dessert Shop  0.06
# 3  Sushi Restaurant  0.06
# 4              Bank  0.06
#
#
# ----The Queensway, Toronto----
#                  venue  freq
# 0           Restaurant  0.19
# 1            BBQ Joint  0.08
# 2   Italian Restaurant  0.08
# 3          Coffee Shop  0.08
# 4  Sporting Goods Shop  0.08
#
#
# ----Thistletown, Toronto----
#                   venue  freq
# 0     Indian Restaurant  0.27
# 1  Caribbean Restaurant  0.18
# 2        Ice Cream Shop  0.09
# 3           Supermarket  0.09
# 4           Coffee Shop  0.09
#
#
# ----Thorncliffe Park, Toronto----
#                 venue  freq
# 0   Indian Restaurant  0.12
# 1   Afghan Restaurant  0.08
# 2         Coffee Shop  0.08
# 3      Sandwich Place  0.08
# 4  Turkish Restaurant  0.08
#
#
# ----Toronto Islands, Toronto----
#              venue  freq
# 0  Harbor / Marina  0.25
# 1             Park  0.25
# 2      Music Venue  0.25
# 3             Café  0.25
# 4              ATM  0.00
#
#
# ----Trinity–Bellwoods, Toronto----
#                    venue  freq
# 0           Cocktail Bar  0.07
# 1                 Bakery  0.07
# 2  Vietnamese Restaurant  0.05
# 3                    Bar  0.05
# 4                   Café  0.05
#
#
# ----Upper Beaches, Toronto----
#                   venue  freq
# 0  Hungarian Restaurant  0.17
# 1                  Park  0.17
# 2           Music Store  0.17
# 3      Asian Restaurant  0.17
# 4           Flower Shop  0.17
#
#
# ----Victoria Village, Toronto----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.33
# 1            Thai Restaurant  0.33
# 2                   Bus Line  0.33
# 3                        ATM  0.00
# 4                  Nightclub  0.00
#
#
# ----Wallace Emerson, Toronto----
#                    venue  freq
# 0            Coffee Shop  0.11
# 1                    Gym  0.11
# 2  Portuguese Restaurant  0.11
# 3               Pharmacy  0.11
# 4            Supermarket  0.05
#
#
# ----West Hill, Toronto----
#                   venue  freq
# 0           Pizza Place  0.09
# 1            Restaurant  0.06
# 2        Breakfast Spot  0.06
# 3  Fast Food Restaurant  0.06
# 4                  Bank  0.06
#
#
# ----West Rouge, Toronto----
#                venue  freq
# 0              Trail   1.0
# 1                ATM   0.0
# 2  Outdoor Sculpture   0.0
# 3    Organic Grocery   0.0
# 4       Optical Shop   0.0
#
#
# ----Westminster, Toronto----
#                   venue  freq
# 0                  Park  0.75
# 1           Coffee Shop  0.25
# 2                   ATM  0.00
# 3  Other Great Outdoors  0.00
# 4       Organic Grocery  0.00
#
#
# ----Westmount, Toronto----
#          venue  freq
# 0  Pizza Place  0.33
# 1  Gas Station  0.33
# 2         Park  0.33
# 3          ATM  0.00
# 4    Nightclub  0.00
#
#
# ----Weston, Toronto----
#                  venue  freq
# 0        Train Station  0.12
# 1  Fried Chicken Joint  0.06
# 2                 Park  0.06
# 3           Laundromat  0.06
# 4          Coffee Shop  0.06
#
#
# ----Wexford, Toronto----
#                  venue  freq
# 0         Burger Joint  0.11
# 1          Pizza Place  0.11
# 2        Grocery Store  0.11
# 3         Intersection  0.05
# 4  Rental Car Location  0.05
#
#
# ----Willowdale, Toronto----
#                   venue  freq
# 0           Coffee Shop  0.15
# 1   Japanese Restaurant  0.06
# 2         Grocery Store  0.06
# 3  Fast Food Restaurant  0.04
# 4          Burger Joint  0.04
#
#
# ----Wilson Heights, Toronto----
#                 venue  freq
# 0        Intersection  0.11
# 1   Convenience Store  0.11
# 2  Italian Restaurant  0.11
# 3       Deli / Bodega  0.11
# 4         Pizza Place  0.11
#
#
# ----Woburn, Toronto----
#                   venue  freq
# 0  Fast Food Restaurant  0.19
# 1        Discount Store  0.10
# 2           Coffee Shop  0.10
# 3                  Bank  0.05
# 4              Pharmacy  0.05
#
#
# ----Wychwood, Toronto----
#                 venue  freq
# 0  Italian Restaurant  0.06
# 1          Restaurant  0.06
# 2         Coffee Shop  0.06
# 3      Ice Cream Shop  0.06
# 4              Bakery  0.04
#
#
# ----York Mills, Toronto----
#              venue  freq
# 0      Coffee Shop  0.20
# 1       Restaurant  0.20
# 2              Gym  0.13
# 3              Pub  0.07
# 4  Thai Restaurant  0.07
#
#
# ----York University Heights, Toronto----
#                   venue  freq
# 0           Pizza Place  0.10
# 1         Grocery Store  0.10
# 2  Fast Food Restaurant  0.10
# 3           Gas Station  0.05
# 4           Coffee Shop  0.05
#
#
# ----Yorkville, Toronto----
#                 venue  freq
# 0            Boutique  0.05
# 1  Italian Restaurant  0.05
# 2                Café  0.04
# 3         Coffee Shop  0.04
# 4          Restaurant  0.04
#               Neighborhood 1st Most Common Venue   2nd Most Common Venue  \
# 0       Agincourt, Toronto    Chinese Restaurant       Korean Restaurant
# 1       Alderwood, Toronto           Pizza Place              Playground
# 2  Alexandra Park, Toronto                   Bar  Furniture / Home Store
# 3         Allenby, Toronto     Fish & Chips Shop      African Restaurant
# 4        Amesbury, Toronto    Athletics & Sports            Intersection
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0          Intersection  Cantonese Restaurant      Asian Restaurant
# 1                   Pub                   Gym           Coffee Shop
# 2                  Café  Caribbean Restaurant              Boutique
# 3                  Café  Fast Food Restaurant          Intersection
# 4                  Park           Gas Station                  Bank
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0         Train Station           Coffee Shop            Food Court
# 1        Sandwich Place      Cuban Restaurant          Cupcake Shop
# 2           Pizza Place    Italian Restaurant                Bakery
# 3         Big Box Store            Restaurant   Filipino Restaurant
# 4           Coffee Shop           Yoga Studio                 Field
#
#    9th Most Common Venue       10th Most Common Venue
# 0  Vietnamese Restaurant         Hong Kong Restaurant
# 1    Dumpling Restaurant  Eastern European Restaurant
# 2           Liquor Store                Poutine Place
# 3            Event Space           Falafel Restaurant
# 4   Ethiopian Restaurant                  Event Space

# %% [markdown]
# #### 3.4. Identify neighborhoods with active Tamil population and evaluate if they have any Indian restaurants <a class="anchor" id="3.4"></a>

# %%
#Narrow down on neighborhoods with active Indian restaurants

Toronto_neighborhoods_venues_sorted
len(Toronto_grouped[Toronto_grouped["Indian Restaurant"] > 0])
Indian_restaurant_nei = Toronto_grouped[["Neighborhood","Indian Restaurant"]]
x=wiki_Toronto_dem.sort_values(['Name'], ascending=True).reset_index()
x.drop(['index'], axis=1, inplace=True)
x

Indian_restaurant_nei
len(Indian_restaurant_nei)
len(x)

y = x[x['Name-ccat'].isin(Indian_restaurant_nei['Neighborhood'])].reset_index()
y.drop(['index'], axis=1, inplace=True)
y

z = pd.DataFrame(Indian_restaurant_nei['Neighborhood'])

z['Indian restaurant freq'] = Indian_restaurant_nei['Indian Restaurant']
z['Ethnicity'] = y['Ethnicity']
z['Ethnicity Percentage (%)'] = y['Ethnicity Percentage (%)']
z['Ethnicity_new'] = y['Ethnicity_new']
z['Latitude'] = y['Latitude']
z['Longitude'] = y['Longitude']
z['Color_ethnicity'] = y['Color_ethnicity']
z['Color_FM'] = y['Color_FM']
z

#z['Indian restaurant freq']
z1 = z[z['Ethnicity_new'] == 'Tamil'].sort_values(by = ['Ethnicity Percentage (%)'], ascending=True)
z1.reset_index(inplace=True)
z1.drop(['index'], axis=1, inplace=True)
z1

#Identify neighborhoods which dont have any Indian restaurants
z2 = z1[z1['Indian restaurant freq'] == 0].sort_values(by = ['Ethnicity Percentage (%)'], ascending=False)
z2.reset_index(inplace=True)
z2.drop(['index'], axis=1, inplace=True)
z2.head()
#z2.sort_values(by = ['Ethnicity Percentage (%)'], ascending=False)
# Out:
#                        Neighborhood  Indian restaurant freq      Ethnicity  \
# 0               Rouge Hill, Toronto                     0.0  Tamil (15.6%)
# 1                  Malvern, Toronto                     0.0  Tamil (12.2%)
# 2      Scarborough Village, Toronto                     0.0  Tamil (11.4%)
# 3              Morningside, Toronto                     0.0  Tamil (10.8%)
# 4  Scarborough City Centre, Toronto                     0.0  Tamil (10.3%)
#
#    Ethnicity Percentage (%) Ethnicity_new Latitude Longitude Color_ethnicity  \
# 0                      15.6         Tamil  43.8049  -79.1658         #a6f89d
# 1                      12.2         Tamil  43.8092  -79.2217         #a6f89d
# 2                      11.4         Tamil  43.7437  -79.2116         #a6f89d
# 3                      10.8         Tamil  43.7826   -79.205         #a6f89d
# 4                      10.3         Tamil   43.717  -79.2547         #a6f89d
#
#   Color_FM
# 0  #4df3ce
# 1  #4df3ce
# 2  #4df3ce
# 3  #4df3ce
# 4  #4df3ce

# %%
#Generate range of colors for based on % of Tamils in each of the above neighborhood

'''import colorsys
N = 5
HSV_tuples = [(x*1.0/N, 0.5, 0.5) for x in range(N)]
RGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)

HSV_tuples = [(0, 1-x/100, 0) for x in z2['Ethnicity Percentage (%)']]
RGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)

print(HSV_tuples)

from sklearn import preprocessing
x_array = np.array(z2['Ethnicity Percentage (%)'])
x_array = x_array/100
x_array

normalized_arr = preprocessing.normalize([x_array])
print(normalized_arr)

x_array = ((x_array-min(x_array))/(max(x_array) - min(x_array)))
x_array
RGB_x_array = map(lambda x: colorsys.hsv_to_rgb(*x), x_array)
RGB_x_array

r1, g1, b1 = [1,0,0]
r2, g2, b2 = [0,1,0]
rdelta, gdelta, bdelta = (r2-r1)/steps, (g2-g1)/steps, (b2-b1)/steps
for step in len(z2['Ethnicity Percentage (%)']):
    r1 += rdelta
    g1 += gdelta
    b1 += bdelta
    output.append((r1, g1, b1))'''
# Out:
# "import colorsys\nN = 5\nHSV_tuples = [(x*1.0/N, 0.5, 0.5) for x in range(N)]\nRGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)\n\nHSV_tuples = [(0, 1-x/100, 0) for x in z2['Ethnicity Percentage (%)']]\nRGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)\n\nprint(HSV_tuples)\n\nfrom sklearn import preprocessing\nx_array = np.array(z2['Ethnicity Percentage (%)'])\nx_array = x_array/100\nx_array\n\nnormalized_arr = preprocessing.normalize([x_array])\nprint(normalized_arr)\n\nx_array = ((x_array-min(x_array))/(max(x_array) - min(x_array)))\nx_array\nRGB_x_array = map(lambda x: colorsys.hsv_to_rgb(*x), x_array)\nRGB_x_array\n\nr1, g1, b1 = [1,0,0]\nr2, g2, b2 = [0,1,0]\nrdelta, gdelta, bdelta = (r2-r1)/steps, (g2-g1)/steps, (b2-b1)/steps\nfor step in len(z2['Ethnicity Percentage (%)']):\n    r1 += rdelta\n    g1 += gdelta\n    b1 += bdelta\n    output.append((r1, g1, b1))"

# %% [markdown]
# #### 3.5. Implement k-means clusterning to develop neighborhood clusters with Indian restaurants, and detailed analysis <a class="anchor" id="3.5"></a>

# %%
#wiki_Toronto_dem
Toronto_grouped

# set number of clusters
kclusters = 3

#Indian_restaurant_nei_clustering = Indian_restaurant_nei.drop('Neighborhood', 1)
Indian_restaurant_nei_clustering = pd.DataFrame(z['Indian restaurant freq'])
Indian_restaurant_nei_clustering
Indian_restaurant_nei

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=1)
kmeans.fit_transform(Indian_restaurant_nei_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:100]

z['Cluster label'] = kmeans.labels_
Indian_restaurant_nei['Cluster label'] = kmeans.labels_
Indian_restaurant_nei

Indian_restaurant_nei_final = Indian_restaurant_nei.join(Toronto_venues.set_index("Neighborhood"), on="Neighborhood")

print(Indian_restaurant_nei_final.shape)
Indian_restaurant_nei_final.head()
#Indian_restaurant_nei_final['Cluster label']
#z[z['Cluster label'] == 2]

z.head()
# Out:
# (3527, 9)
# C:\Users\Bhuvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               Neighborhood  Indian restaurant freq          Ethnicity  \
# 0       Agincourt, Toronto                     0.0  Cantonese (19.3%)
# 1       Alderwood, Toronto                     0.0      Polish (6.2%)
# 2  Alexandra Park, Toronto                     0.0  Cantonese (17.9%)
# 3         Allenby, Toronto                     0.0     Russian (1.4%)
# 4        Amesbury, Toronto                     0.0     Spanish (6.1%)
#
#    Ethnicity Percentage (%) Ethnicity_new Latitude Longitude Color_ethnicity  \
# 0                      19.3     Cantonese  43.7854  -79.2785         #58f8c9
# 1                       6.2        Polish  43.6017  -79.5452         #6e1cff
# 2                      17.9     Cantonese  43.6508  -79.4043         #58f8c9
# 3                       1.4       Russian  43.7114  -79.5534         #6dfdbf
# 4                       6.1       Spanish  43.7062  -79.4835         #08bee9
#
#   Color_FM  Cluster label
# 0  #4df3ce              2
# 1  #1996f3              2
# 2  #b2f396              2
# 3  #b2f396              2
# 4  #ff964f              2

# %%
# Print map of Toronto displaying the neighborhood clusters based on frequency of Indian restaurant

map_clusters = folium.Map(location=[Toronto_latitude, Toronto_longitude],zoom_start=14)

# add markers to the map
markers_colors={}
markers_colors[0] = 'red'
markers_colors[1] = 'blue'
markers_colors[2] = 'green'
markers_colors[3] = 'yellow'
markers_colors[4] = 'cyan'
markers_colors[5] = 'black'
for lat, lon, cluster, label in zip(z['Latitude'],
                             z['Longitude'],
                             z['Cluster label'],
                             z['Cluster label']):
    
    label = folium.Popup('Cluster no: {}'.format(str(label)), parse_html=True)
    folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup = label,
            color =markers_colors[cluster],
            fill = True,
            fill_color=markers_colors[cluster],
            fill_opacity=1
            ).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_4fa50be1dfdd4a54b71b31049934559e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4fa50be1dfdd4a54b71b31049934559e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4fa50be1dfdd4a54b71b31049934559e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_4fa50be1dfdd4a54b71b31049934559e%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2014%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
z[z['Cluster label'] == 2].max()

# min = 0.02, max = 0.066667 (cluster 0)
# min = 0.1, max = 0.272727 (cluster 1)
# min = 0, max = 0.0178571 (cluster 2)
# Out:
# Neighborhood                York University Heights, Toronto
# Indian restaurant freq                             0.0178571
# Ethnicity                                  Vietnamese (6.9%)
# Ethnicity Percentage (%)                                31.4
# Ethnicity_new                                     Vietnamese
# Latitude                                             43.8232
# Longitude                                           -79.1305
# Color_ethnicity                                      #ffa95b
# Color_FM                                             #ff964f
# Cluster label                                              2
# dtype: object

# %%
# Print map of Toronto displaying the neighborhood clusters based on boroughs and Tamil population demography. Mark neighborhoods with high prospects.


# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[Toronto_latitude, Toronto_longitude], zoom_start=11)

wiki_Toronto_nei = wiki_Toronto_nei.dropna()


# add markers to map
for lat, lng, label, area, color_ethnicity, color_FM in zip(wiki_Toronto_dem['Latitude'],
                                                      wiki_Toronto_dem['Longitude'],
                                                      wiki_Toronto_dem['Ethnicity_new'],
                                                      wiki_Toronto_dem['Name'],                                                            
                                                      wiki_Toronto_dem['Color_ethnicity'],
                                                      wiki_Toronto_dem['Color_FM']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=color_FM,
        fill=True,
        fill_color=color_FM,
        fill_opacity=1,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto


z1
z2 = z1[z1['Indian restaurant freq'] == 0]
z2


# Overlay Tamil restaurants atop the neighborhoods

for lat, lng, label, neighborhood in zip(z2['Latitude'],
                                         z2['Longitude'],
                                         z2['Ethnicity'],
                                         z2['Neighborhood']):
    label = folium.Popup('Location: {}, Ethnicity: {}'.format(neighborhood, label), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0).add_to(map_Toronto) 
     
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_db234f4015ac425b8b6795d31667a8bc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_db234f4015ac425b8b6795d31667a8bc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_db234f4015ac425b8b6795d31667a8bc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_db234f4015ac425b8b6795d31667a8bc%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Top 5 neighborhoods with high Tamil population and without any Indian restaurant

z2.head()
# Out:
#                        Neighborhood  Indian restaurant freq      Ethnicity  \
# 0               Cliffcrest, Toronto                     0.0   Tamil (1.5%)
# 2                  Bendale, Toronto                     0.0   Tamil (3.7%)
# 3     Scarborough Junction, Toronto                     0.0   Tamil (4.2%)
# 4           Highland Creek, Toronto                     0.0   Tamil (5.1%)
# 7  Scarborough City Centre, Toronto                     0.0  Tamil (10.3%)
#
#    Ethnicity Percentage (%) Ethnicity_new Latitude Longitude Color_ethnicity  \
# 0                       1.5         Tamil  43.7218  -79.2362         #a6f89d
# 2                       3.7         Tamil  43.7535  -79.2553         #a6f89d
# 3                       4.2         Tamil   43.716  -79.2607         #a6f89d
# 4                       5.1         Tamil  43.7901  -79.1733         #a6f89d
# 7                      10.3         Tamil   43.717  -79.2547         #a6f89d
#
#   Color_FM
# 0  #4df3ce
# 2  #4df3ce
# 3  #4df3ce
# 4  #4df3ce
# 7  #4df3ce

# %%
test = z.loc[z['Cluster label'] == 0]
test
wiki_Toronto_dem
Toronto_neighborhoods_venues_sorted
z

Toronto_merged = z.join(Toronto_neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged = Toronto_merged.dropna().reset_index(drop=True)

# %% [markdown]
# ### Analyze Cluster #0

# %%
#Analyse Cluser #1:

test = Toronto_merged.loc[z['Cluster label'] == 0, Toronto_merged.columns[[1] + list(range(19, Toronto_merged.shape[1]))]]
test

#, z.columns[[1] + list(range(19, z.shape[1]))]\

#Find the top 3 places in each ranking list:

"""for column in test.columns[1:]:
    print('------------{}------------'.format(column))
    print(test[column].value_counts().head(3))
    print('\n')"""

#Extract columns 
x = test.iloc[:,1:]
x.mode().iloc[0,:]    

#Wuery the list of all activities
activities = Toronto_grouped.columns
activities

Cluster1_all = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False)
Cluster1_top10 = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False).head(10)
Cluster1_bottom10 = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False).tail(10)
Cluster1_top10


print('----------- CLUSTER#1 TOP 10 -----------')
#print('\n')
print(Cluster1_top10)
print('\n')


print('----------- CLUSTER#1 BOTTOM 10 -----------')
#print('\n')
print(Cluster1_bottom10)

# Count the frequency of occurence of every event
Cluster1_all
y = pd.DataFrame(Cluster1_all,columns =['Freq'])
y.index.name = 'Event'
y

# Filter the popular cuisine (restaurants)
filter_restaurants = y[y.index.str.contains('Rest')]
filter_restaurants

# Filter the popular shops 
filter_shops = y[y.index.str.contains('Shop','Store')]
filter_shops

filter_restaurants
#Cluster1_all
y
# Out:
# ----------- CLUSTER#1 TOP 10 -----------
# Indian Restaurant      3
# Restaurant             2
# Liquor Store           1
# Japanese Restaurant    1
# Supermarket            1
# Bank                   1
# Dessert Shop           1
# Café                   1
# Scenic Lookout         1
# Beer Store             1
# dtype: int64
#
#
# ----------- CLUSTER#1 BOTTOM 10 -----------
# Scenic Lookout         1
# Beer Store             1
# Juice Bar              1
# Pub                    1
# Event Space            1
# Museum                 1
# Baby Store             1
# Sushi Restaurant       1
# Bus Stop               1
# Fried Chicken Joint    1
# dtype: int64
#                      Freq
# Event
# Indian Restaurant       3
# Restaurant              2
# Liquor Store            1
# Japanese Restaurant     1
# Supermarket             1
# Bank                    1
# Dessert Shop            1
# Café                    1
# Scenic Lookout          1
# Beer Store              1
# Juice Bar               1
# Pub                     1
# Event Space             1
# Museum                  1
# Baby Store              1
# Sushi Restaurant        1
# Bus Stop                1
# Fried Chicken Joint     1

# %% [markdown]
# #### Analyzing cluster #0 we learn that:
# 1. Most of the neighborhoods in Central/South-Western Toronto have a healthy concentration of Indian restaurants
# 2. Majority of the Indian restaurants would fit within this cluster bubble and are in the University district surrounding University of Toronto
# 3. Possibly the focus/target population are the International students from India

# %% [markdown]
# ### Analyze Cluster #1

# %%
test = Toronto_merged.loc[z['Cluster label'] == 1, Toronto_merged.columns[[1] + list(range(19, Toronto_merged.shape[1]))]]
test

#Find the top 3 places in each ranking list
"""for column in test.columns[1:]:
    print('------------{}------------'.format(column))
    print(test[column].value_counts().head(3))
    print('\n')"""
    
    

#Extract columns 
x = test.iloc[:,1:]
x.mode().iloc[0,:]    

#Wuery the list of all activities
activities = Toronto_grouped.columns
activities

Cluster1_all = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False)
Cluster1_top10 = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False).head(10)
Cluster1_bottom10 = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False).tail(10)
Cluster1_top10


print('----------- CLUSTER#1 TOP 10 -----------')
#print('\n')
print(Cluster1_top10)
print('\n')


print('----------- CLUSTER#1 BOTTOM 10 -----------')
#print('\n')
print(Cluster1_bottom10)
print('\n')


# Count the frequency of occurence of every event
Cluster1_all
y = pd.DataFrame(Cluster1_all,columns =['Freq'])
y.index.name = 'Event'
y

# Filter the popular cuisine (restaurants)
filter_restaurants = y[y.index.str.contains('Rest')]
filter_restaurants

# Filter the popular shops 
filter_shops = y[y.index.str.contains('Shop','Store')]
#filter_shops

filter_restaurants
#Cluster1_all
# Out:
# ----------- CLUSTER#1 TOP 10 -----------
# Electronics Store       2
# Beer Store              1
# Food & Drink Shop       1
# Ethiopian Restaurant    1
# Restaurant              1
# Discount Store          1
# dtype: int64
#
#
# ----------- CLUSTER#1 BOTTOM 10 -----------
# Electronics Store       2
# Beer Store              1
# Food & Drink Shop       1
# Ethiopian Restaurant    1
# Restaurant              1
# Discount Store          1
# dtype: int64
#                       Freq
# Event
# Ethiopian Restaurant     1
# Restaurant               1

# %% [markdown]
# #### Analyzing cluster #1 we learn that:
# 1. The marked blue blips constitute the highest frequency of Indian restaurants and are distributed sparsely across the city.
# 2. Contrary to the popular expectation only 2 high frequency blips (Scarborough East, Eglinton) are in the Western part of the city, which have the high population of Tamils.
# 3. Can likely infer that the existing restaurants primarily target the larger population base who may be more interested in the popular Indian recipes, with limited interest in traditional South Indian recipes.

# %% [markdown]
# ### Analyze Cluster #2

# %%
#Analyse Cluser #2

test = Toronto_merged.loc[z['Cluster label'] == 2, Toronto_merged.columns[[1] + list(range(19, Toronto_merged.shape[1]))]]
test

#Find the top 3 places in each ranking list
"""for column in test.columns[1:]:
    print('------------{}------------'.format(column))
    print(test[column].value_counts().head(3))
    print('\n')"""
    
    

#Extract columns 
x = test.iloc[:,1:]
x.mode().iloc[0,:]    

#Wuery the list of all activities
activities = Toronto_grouped.columns
activities

Cluster1_all = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False)
Cluster1_top10 = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False).head(10)
Cluster1_bottom10 = x.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False).tail(10)
Cluster1_top10


print('----------- CLUSTER#1 TOP 10 -----------')
#print('\n')
print(Cluster1_top10)
#print('\n')


print('----------- CLUSTER#1 BOTTOM 10 -----------')
#print('\n')
print(Cluster1_bottom10)

# Count the frequency of occurence of every event
Cluster1_all
y = pd.DataFrame(Cluster1_all,columns =['Freq'])
y.index.name = 'Event'
y

# Filter the popular cuisine (restaurants)
filter_restaurants = y[y.index.str.contains('Rest')]
filter_restaurants

# Filter the popular shops 
filter_shops = y[y.index.str.contains('Shop','Store')]
filter_shops

filter_restaurants
#Cluster1_all
# Out:
# ----------- CLUSTER#1 TOP 10 -----------
# Fast Food Restaurant    19
# Farmers Market          16
# Filipino Restaurant     10
# Field                    8
# Event Space              8
# Falafel Restaurant       7
# Grocery Store            4
# Park                     3
# Coffee Shop              3
# Fish & Chips Shop        3
# dtype: int64
# ----------- CLUSTER#1 BOTTOM 10 -----------
# Burger Joint                 1
# Electronics Store            1
# Music Venue                  1
# Middle Eastern Restaurant    1
# Gourmet Shop                 1
# Taco Place                   1
# Dessert Shop                 1
# Poutine Place                1
# Scenic Lookout               1
# Food & Drink Shop            1
# dtype: int64
#                              Freq
# Event
# Fast Food Restaurant           19
# Filipino Restaurant            10
# Falafel Restaurant              7
# Ethiopian Restaurant            3
# Italian Restaurant              2
# Korean Restaurant               2
# Comfort Food Restaurant         1
# Japanese Restaurant             1
# Caribbean Restaurant            1
# Eastern European Restaurant     1
# Hong Kong Restaurant            1
# American Restaurant             1
# Seafood Restaurant              1
# Sushi Restaurant                1
# French Restaurant               1
# Middle Eastern Restaurant       1

# %% [markdown]
# #### Analyzing cluster #2 we learn that:
# 1. Most of the neighborhoods in Toronto don't have any Indian restaurants (green blips), signaling that it's more of an exquisite cuisine and not a contemporary food preference.
# 2. Surprisingly, Western Toronto is densely populated with these green blips indicating lack of Indian/South-Indian restaurants that are near the Tamil community.
# 3. Flipping the green blips to red/blue would encourage the Tamil community to benefit from Indian restaurants without farther commute to Central/South-Western Toronto

# %% [markdown]
# ### Conclusions and Recommendations <a class="anchor" id="4"></a>
#
# 1. Based on the above analysis, the top 5 locations to start a dedicated South-Indian restaurant with their corresponding Tamil population are:<br>
#     a.Rouge Hill (15.6%)<br>
#     b.Malvern (12.2%)<br>
#     c.Scarborough Village (11.4%)<br>
#     d.Morningside (10.8%)<br>
#     e.Scarborough City Centre (10.3%)<br><br>
#
# 2. The above neighborhoods offer competitive advantage as they dont have any Indian restaurants, thus increasing the probability of success <br>
#
# 3. Most of the Tamil population is concentrated in Scarborough, which surprisingly has limited choice of Indian restaurants<br>
#
# 4. The taxation, rules and business  guidelines corresponding to the city of Scarborough would be in effect for the list of recommended locations <br><br><br>
#
# The following map highlights the list of recommmended locations (highlighted  in black border) for starting a dedicted South Indian restaurant in Toronto:

# %%
# Print map of Toronto displaying the neighborhood clusters based on boroughs and Tamil population demography. Mark neighborhoods with high prospects.


# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[Toronto_latitude, Toronto_longitude], zoom_start=11)

wiki_Toronto_nei = wiki_Toronto_nei.dropna()


# add markers to map
for lat, lng, label, area, color_ethnicity, color_FM in zip(wiki_Toronto_dem['Latitude'],
                                                      wiki_Toronto_dem['Longitude'],
                                                      wiki_Toronto_dem['Ethnicity_new'],
                                                      wiki_Toronto_dem['Name'],                                                            
                                                      wiki_Toronto_dem['Color_ethnicity'],
                                                      wiki_Toronto_dem['Color_FM']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=color_FM,
        fill=True,
        fill_color=color_FM,
        fill_opacity=1,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto


z1
z2 = z1[z1['Indian restaurant freq'] == 0]
z2


# Overlay Tamil restaurants atop the neighborhoods

for lat, lng, label, neighborhood in zip(z2['Latitude'],
                                         z2['Longitude'],
                                         z2['Ethnicity'],
                                         z2['Neighborhood']):
    label = folium.Popup('Location: {}, Ethnicity: {}'.format(neighborhood, label), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='black',
        fill=True,
        fill_color='black',
        fill_opacity=0).add_to(map_Toronto) 
     
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f52c8c33afd34f78bd87b0c28a4fa4a1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f52c8c33afd34f78bd87b0c28a4fa4a1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f52c8c33afd34f78bd87b0c28a4fa4a1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f52c8c33afd34f78bd87b0c28a4fa4a1%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...
